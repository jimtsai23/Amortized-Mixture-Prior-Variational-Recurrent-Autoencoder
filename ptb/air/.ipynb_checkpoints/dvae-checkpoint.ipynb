# %%
import sys
sys.path.append('..')

# %%
import os
import time
import math
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from sklearn.manifold import TSNE
from multiprocessing import cpu_count

# %%
from ptb import PTB
from dvae.dvae_model import RNNVAE
from utils import linear_anneal

# %%
# device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Penn TreeBank (PTB) dataset
data_path = '../data'
max_len = 96
splits = ['train', 'valid', 'test']
datasets = {split: PTB(root=data_path, split=split) for split in splits}

# %%
# data loader
batch_size = 32
dataloaders = {split: DataLoader(datasets[split],
                                 batch_size=batch_size,
                                 shuffle=split=='train',
                                 num_workers=cpu_count(),
                                 pin_memory=torch.cuda.is_available())
                                 for split in splits}
symbols = datasets['train'].symbols

# %%
# RNNVAE model
embedding_size = 300
hidden_size = 256
latent_dim = 16
dropout_rate = 0.5
model = RNNVAE(vocab_size=datasets['train'].vocab_size,
               embed_size=embedding_size,
               time_step=max_len,
               hidden_size=hidden_size,
               z_dim=latent_dim,
               dropout_rate=dropout_rate,
               bos_idx=symbols['<bos>'],
               eos_idx=symbols['<eos>'],
               pad_idx=symbols['<pad>'])
model = model.to(device)

# %%
# folder to save model
save_path = 'linear'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
# objective function
learning_rate = 0.001
criterion = nn.NLLLoss(size_average=False, ignore_index=symbols['<pad>'])
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# negative log likelihood
def NLL(logp, target, length):
    target = target[:, :torch.max(length).item()].contiguous().view(-1)
    logp = logp.view(-1, logp.size(-1))
    return criterion(logp, target)

# KL divergence
def KL_div(mu, logvar):
    return -0.5 * torch.sum(1. + logvar - mu.pow(2) - logvar.exp())

# %%
# training setting
epoch = 20
print_every = 50

# %%
# training interface
step = 0
tracker = {'ELBO': [], 'NLL': [], 'KL': [], 'KL_weight': []}
start_time = time.time()
for ep in range(epoch):
    # learning rate decay
    if ep >= 10 and ep % 2 == 0:
        learning_rate = learning_rate * 0.5
        for param_group in optimizer.param_groups:
            param_group['lr'] = learning_rate

    for split in splits:
        dataloader = dataloaders[split]
        model.train() if split == 'train' else model.eval()
        totals = {'ELBO': 0., 'NLL': 0., 'KL': 0., 'words': 0}

        for itr, (enc_inputs, dec_inputs, targets, lengths) in enumerate(dataloader):
            bsize = enc_inputs.size(0)
            enc_inputs = enc_inputs.to(device)
            dec_inputs = dec_inputs.to(device)
            targets = targets.to(device)
            lengths = lengths.to(device)

            # forward
            logp, mu, logvar = model(enc_inputs, dec_inputs, lengths)

            # calculate loss
            NLL_loss = NLL(logp, targets, lengths + 1)
            KL_loss = KL_div(mu, logvar)
            #KL_weight = linear_anneal(step, len(dataloaders['train']) * 10)
            KL_weight = 1
            loss = (NLL_loss + KL_weight * KL_loss) / bsize

            # cumulate
            totals['ELBO'] += loss.item() * bsize
            totals['NLL'] += NLL_loss.item()
            totals['KL'] += KL_loss.item()
            totals['words'] += torch.sum(lengths).item()

            # backward and optimize
            if split == 'train':
                step += 1
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), 5)
                optimizer.step()

                # track
                tracker['ELBO'].append(loss.item())
                tracker['NLL'].append(NLL_loss.item() / bsize)
                tracker['KL'].append(KL_loss.item() / bsize)
                tracker['KL_weight'].append(KL_weight)

                # print statistics
                if itr % print_every == 0 or itr + 1 == len(dataloader):
                    print("%s Batch %04d/%04d, ELBO-Loss %.4f, "
                          "NLL-Loss %.4f, KL-Loss %.4f, KL-Weight %.4f"
                          % (split.upper(), itr, len(dataloader),
                             tracker['ELBO'][-1], tracker['NLL'][-1],
                             tracker['KL'][-1], tracker['KL_weight'][-1]))

        samples = len(datasets[split])
        print("%s Epoch %02d/%02d, ELBO %.4f, NLL %.4f, KL %.4f, PPL %.4f"
              % (split.upper(), ep, epoch, totals['ELBO'] / samples,
                 totals['NLL'] / samples, totals['KL'] / samples,
                 math.exp(totals['NLL'] / totals['words'])))

    # save checkpoint
    checkpoint_path = os.path.join(save_path, "E%02d.pkl" % ep)
    torch.save(model.state_dict(), checkpoint_path)
    print("Model saved at %s\n" % checkpoint_path)
end_time = time.time()
print('Total cost time',
      time.strftime("%H hr %M min %S sec", time.gmtime(end_time - start_time)))
# Out:
# TRAIN Batch 0000/1315, ELBO-Loss 202.7017, NLL-Loss 202.6991, KL-Loss 0.2685, KL-Weight 0.0100
# TRAIN Batch 0050/1315, ELBO-Loss 145.2624, NLL-Loss 145.1845, KL-Loss 5.6444, KL-Weight 0.0138
# TRAIN Batch 0100/1315, ELBO-Loss 132.4237, NLL-Loss 132.2253, KL-Loss 11.2682, KL-Weight 0.0176
# TRAIN Batch 0150/1315, ELBO-Loss 131.5054, NLL-Loss 131.2304, KL-Loss 12.8447, KL-Weight 0.0214
# TRAIN Batch 0200/1315, ELBO-Loss 132.1104, NLL-Loss 131.7527, KL-Loss 14.1898, KL-Weight 0.0252
# TRAIN Batch 0250/1315, ELBO-Loss 145.1129, NLL-Loss 144.6457, KL-Loss 16.1032, KL-Weight 0.0290
# TRAIN Batch 0300/1315, ELBO-Loss 126.6238, NLL-Loss 126.0693, KL-Loss 16.8982, KL-Weight 0.0328
# TRAIN Batch 0350/1315, ELBO-Loss 129.5501, NLL-Loss 128.8884, KL-Loss 18.0714, KL-Weight 0.0366
# TRAIN Batch 0400/1315, ELBO-Loss 121.4847, NLL-Loss 120.8086, KL-Loss 16.7286, KL-Weight 0.0404
# TRAIN Batch 0450/1315, ELBO-Loss 129.5624, NLL-Loss 128.6852, KL-Loss 19.8375, KL-Weight 0.0442
# TRAIN Batch 0500/1315, ELBO-Loss 124.1439, NLL-Loss 123.1632, KL-Loss 20.4201, KL-Weight 0.0480
# TRAIN Batch 0550/1315, ELBO-Loss 113.7326, NLL-Loss 112.8026, KL-Loss 17.9467, KL-Weight 0.0518
# TRAIN Batch 0600/1315, ELBO-Loss 119.1260, NLL-Loss 117.9761, KL-Loss 20.6713, KL-Weight 0.0556
# TRAIN Batch 0650/1315, ELBO-Loss 116.5453, NLL-Loss 115.3678, KL-Loss 19.8134, KL-Weight 0.0594
# TRAIN Batch 0700/1315, ELBO-Loss 116.1555, NLL-Loss 114.8795, KL-Loss 20.1788, KL-Weight 0.0632
# TRAIN Batch 0750/1315, ELBO-Loss 144.2413, NLL-Loss 142.6286, KL-Loss 24.0585, KL-Weight 0.0670
# TRAIN Batch 0800/1315, ELBO-Loss 121.3089, NLL-Loss 119.9803, KL-Loss 18.7551, KL-Weight 0.0708
# TRAIN Batch 0850/1315, ELBO-Loss 123.8720, NLL-Loss 122.3583, KL-Loss 20.2802, KL-Weight 0.0746
# TRAIN Batch 0900/1315, ELBO-Loss 117.4466, NLL-Loss 115.8714, KL-Loss 20.0809, KL-Weight 0.0784
# TRAIN Batch 0950/1315, ELBO-Loss 122.5023, NLL-Loss 120.6983, KL-Loss 21.9350, KL-Weight 0.0822
# TRAIN Batch 1000/1315, ELBO-Loss 126.7558, NLL-Loss 124.8094, KL-Loss 22.6207, KL-Weight 0.0860
# TRAIN Batch 1050/1315, ELBO-Loss 110.0381, NLL-Loss 108.2815, KL-Loss 19.5504, KL-Weight 0.0898
# TRAIN Batch 1100/1315, ELBO-Loss 113.6922, NLL-Loss 111.5676, KL-Loss 22.6867, KL-Weight 0.0937
# TRAIN Batch 1150/1315, ELBO-Loss 139.0338, NLL-Loss 136.6038, KL-Loss 24.9350, KL-Weight 0.0975
# TRAIN Batch 1200/1315, ELBO-Loss 120.8996, NLL-Loss 118.7639, KL-Loss 21.0915, KL-Weight 0.1013
# TRAIN Batch 1250/1315, ELBO-Loss 120.3627, NLL-Loss 118.1846, KL-Loss 20.7323, KL-Weight 0.1051
# TRAIN Batch 1300/1315, ELBO-Loss 121.3446, NLL-Loss 119.0651, KL-Loss 20.9400, KL-Weight 0.1089
# TRAIN Batch 1314/1315, ELBO-Loss 120.9955, NLL-Loss 118.8226, KL-Loss 19.7673, KL-Weight 0.1099
# TRAIN Epoch 00/20, ELBO 127.6831, NLL 126.4605, KL 19.6777, PPL 401.0788
# VALID Epoch 00/20, ELBO 114.8527, NLL 112.6257, KL 20.2451, PPL 219.6602
# TEST Epoch 00/20, ELBO 113.9099, NLL 111.6684, KL 20.3779, PPL 208.2273
# Model saved at linear/E00.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 105.3716, NLL-Loss 103.2403, KL-Loss 19.3758, KL-Weight 0.1100
# TRAIN Batch 0050/1315, ELBO-Loss 104.1302, NLL-Loss 101.7920, KL-Loss 20.5465, KL-Weight 0.1138
# TRAIN Batch 0100/1315, ELBO-Loss 95.5091, NLL-Loss 93.2431, KL-Loss 19.2680, KL-Weight 0.1176
# TRAIN Batch 0150/1315, ELBO-Loss 98.9500, NLL-Loss 96.3440, KL-Loss 21.4650, KL-Weight 0.1214
# TRAIN Batch 0200/1315, ELBO-Loss 114.2156, NLL-Loss 111.6132, KL-Loss 20.7847, KL-Weight 0.1252
# TRAIN Batch 0250/1315, ELBO-Loss 119.4025, NLL-Loss 116.5224, KL-Loss 22.3244, KL-Weight 0.1290
# TRAIN Batch 0300/1315, ELBO-Loss 108.4155, NLL-Loss 105.6828, KL-Loss 20.5752, KL-Weight 0.1328
# TRAIN Batch 0350/1315, ELBO-Loss 112.2360, NLL-Loss 109.4075, KL-Loss 20.7039, KL-Weight 0.1366
# TRAIN Batch 0400/1315, ELBO-Loss 113.6996, NLL-Loss 110.7631, KL-Loss 20.9130, KL-Weight 0.1404
# TRAIN Batch 0450/1315, ELBO-Loss 100.9834, NLL-Loss 97.9929, KL-Loss 20.7353, KL-Weight 0.1442
# TRAIN Batch 0500/1315, ELBO-Loss 139.0142, NLL-Loss 135.4614, KL-Loss 24.0017, KL-Weight 0.1480
# TRAIN Batch 0550/1315, ELBO-Loss 118.3686, NLL-Loss 115.0480, KL-Loss 21.8713, KL-Weight 0.1518
# TRAIN Batch 0600/1315, ELBO-Loss 102.5748, NLL-Loss 99.5486, KL-Loss 19.4452, KL-Weight 0.1556
# TRAIN Batch 0650/1315, ELBO-Loss 106.0975, NLL-Loss 102.9093, KL-Loss 19.9977, KL-Weight 0.1594
# TRAIN Batch 0700/1315, ELBO-Loss 108.1308, NLL-Loss 104.9416, KL-Loss 19.5377, KL-Weight 0.1632
# TRAIN Batch 0750/1315, ELBO-Loss 113.4748, NLL-Loss 109.9756, KL-Loss 20.9488, KL-Weight 0.1670
# TRAIN Batch 0800/1315, ELBO-Loss 105.5001, NLL-Loss 102.0433, KL-Loss 20.2347, KL-Weight 0.1708
# TRAIN Batch 0850/1315, ELBO-Loss 107.7886, NLL-Loss 104.3525, KL-Loss 19.6759, KL-Weight 0.1746
# TRAIN Batch 0900/1315, ELBO-Loss 102.7068, NLL-Loss 98.9442, KL-Loss 21.0860, KL-Weight 0.1784
# TRAIN Batch 0950/1315, ELBO-Loss 98.5175, NLL-Loss 94.9064, KL-Loss 19.8149, KL-Weight 0.1822
# TRAIN Batch 1000/1315, ELBO-Loss 111.9586, NLL-Loss 108.2380, KL-Loss 19.9981, KL-Weight 0.1860
# TRAIN Batch 1050/1315, ELBO-Loss 112.8850, NLL-Loss 108.9879, KL-Loss 20.5278, KL-Weight 0.1898
# TRAIN Batch 1100/1315, ELBO-Loss 108.7759, NLL-Loss 104.9373, KL-Loss 19.8223, KL-Weight 0.1937
# TRAIN Batch 1150/1315, ELBO-Loss 106.2279, NLL-Loss 102.3776, KL-Loss 19.5000, KL-Weight 0.1975
# TRAIN Batch 1200/1315, ELBO-Loss 110.8782, NLL-Loss 106.8652, KL-Loss 19.9399, KL-Weight 0.2013
# TRAIN Batch 1250/1315, ELBO-Loss 91.7157, NLL-Loss 87.8365, KL-Loss 18.9176, KL-Weight 0.2051
# TRAIN Batch 1300/1315, ELBO-Loss 114.4479, NLL-Loss 110.2360, KL-Loss 20.1659, KL-Weight 0.2089
# TRAIN Batch 1314/1315, ELBO-Loss 111.6329, NLL-Loss 107.2355, KL-Loss 20.9474, KL-Weight 0.2099
# TRAIN Epoch 01/20, ELBO 113.3807, NLL 110.0653, KL 20.8031, PPL 184.3865
# VALID Epoch 01/20, ELBO 109.2293, NLL 104.9301, KL 20.4728, PPL 151.9641
# TEST Epoch 01/20, ELBO 108.3920, NLL 104.0575, KL 20.6403, PPL 144.7159
# Model saved at linear/E01.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 115.4153, NLL-Loss 111.0452, KL-Loss 20.8101, KL-Weight 0.2100
# TRAIN Batch 0050/1315, ELBO-Loss 106.9096, NLL-Loss 102.8791, KL-Loss 18.8514, KL-Weight 0.2138
# TRAIN Batch 0100/1315, ELBO-Loss 112.8258, NLL-Loss 108.2295, KL-Loss 21.1221, KL-Weight 0.2176
# TRAIN Batch 0150/1315, ELBO-Loss 110.8712, NLL-Loss 106.3411, KL-Loss 20.4607, KL-Weight 0.2214
# TRAIN Batch 0200/1315, ELBO-Loss 102.6731, NLL-Loss 97.9332, KL-Loss 21.0467, KL-Weight 0.2252
# TRAIN Batch 0250/1315, ELBO-Loss 105.6907, NLL-Loss 101.2901, KL-Loss 19.2157, KL-Weight 0.2290
# TRAIN Batch 0300/1315, ELBO-Loss 123.8702, NLL-Loss 118.7537, KL-Loss 21.9767, KL-Weight 0.2328
# TRAIN Batch 0350/1315, ELBO-Loss 105.9244, NLL-Loss 101.2048, KL-Loss 19.9460, KL-Weight 0.2366
# TRAIN Batch 0400/1315, ELBO-Loss 112.4317, NLL-Loss 107.7948, KL-Loss 19.2868, KL-Weight 0.2404
# TRAIN Batch 0450/1315, ELBO-Loss 103.2754, NLL-Loss 98.2756, KL-Loss 20.4723, KL-Weight 0.2442
# TRAIN Batch 0500/1315, ELBO-Loss 105.6699, NLL-Loss 101.0533, KL-Loss 18.6136, KL-Weight 0.2480
# TRAIN Batch 0550/1315, ELBO-Loss 96.4261, NLL-Loss 91.7957, KL-Loss 18.3872, KL-Weight 0.2518
# TRAIN Batch 0600/1315, ELBO-Loss 110.2553, NLL-Loss 105.4285, KL-Loss 18.8824, KL-Weight 0.2556
# TRAIN Batch 0650/1315, ELBO-Loss 144.2379, NLL-Loss 138.3869, KL-Loss 22.5533, KL-Weight 0.2594
# TRAIN Batch 0700/1315, ELBO-Loss 105.9725, NLL-Loss 100.5894, KL-Loss 20.4499, KL-Weight 0.2632
# TRAIN Batch 0750/1315, ELBO-Loss 89.8394, NLL-Loss 85.1024, KL-Loss 17.7395, KL-Weight 0.2670
# TRAIN Batch 0800/1315, ELBO-Loss 102.1946, NLL-Loss 97.2157, KL-Loss 18.3834, KL-Weight 0.2708
# TRAIN Batch 0850/1315, ELBO-Loss 112.1876, NLL-Loss 107.1300, KL-Loss 18.4153, KL-Weight 0.2746
# TRAIN Batch 0900/1315, ELBO-Loss 114.6770, NLL-Loss 109.2360, KL-Loss 19.5408, KL-Weight 0.2784
# TRAIN Batch 0950/1315, ELBO-Loss 81.7345, NLL-Loss 76.7119, KL-Loss 17.7954, KL-Weight 0.2822
# TRAIN Batch 1000/1315, ELBO-Loss 90.2231, NLL-Loss 85.0868, KL-Loss 17.9562, KL-Weight 0.2860
# TRAIN Batch 1050/1315, ELBO-Loss 99.1362, NLL-Loss 94.0291, KL-Loss 17.6198, KL-Weight 0.2898
# TRAIN Batch 1100/1315, ELBO-Loss 118.3131, NLL-Loss 112.6985, KL-Loss 19.1200, KL-Weight 0.2937
# TRAIN Batch 1150/1315, ELBO-Loss 101.7622, NLL-Loss 96.2164, KL-Loss 18.6443, KL-Weight 0.2975
# TRAIN Batch 1200/1315, ELBO-Loss 115.1197, NLL-Loss 109.4623, KL-Loss 18.7794, KL-Weight 0.3013
# TRAIN Batch 1250/1315, ELBO-Loss 98.6248, NLL-Loss 93.0359, KL-Loss 18.3207, KL-Weight 0.3051
# TRAIN Batch 1300/1315, ELBO-Loss 107.7677, NLL-Loss 101.8999, KL-Loss 18.9983, KL-Weight 0.3089
# TRAIN Batch 1314/1315, ELBO-Loss 102.4809, NLL-Loss 96.9948, KL-Loss 17.7014, KL-Weight 0.3099
# TRAIN Epoch 02/20, ELBO 108.5775, NLL 103.5453, KL 19.4238, PPL 135.3669
# VALID Epoch 02/20, ELBO 107.6346, NLL 101.8455, KL 18.6743, PPL 131.1011
# TEST Epoch 02/20, ELBO 106.9642, NLL 101.1549, KL 18.7395, PPL 125.9651
# Model saved at linear/E02.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 113.3194, NLL-Loss 107.5469, KL-Loss 18.6209, KL-Weight 0.3100
# TRAIN Batch 0050/1315, ELBO-Loss 101.0173, NLL-Loss 95.1364, KL-Loss 18.7409, KL-Weight 0.3138
# TRAIN Batch 0100/1315, ELBO-Loss 106.9581, NLL-Loss 100.6618, KL-Loss 19.8244, KL-Weight 0.3176
# TRAIN Batch 0150/1315, ELBO-Loss 103.8616, NLL-Loss 97.8606, KL-Loss 18.6712, KL-Weight 0.3214
# TRAIN Batch 0200/1315, ELBO-Loss 104.8958, NLL-Loss 99.0501, KL-Loss 17.9754, KL-Weight 0.3252
# TRAIN Batch 0250/1315, ELBO-Loss 118.4871, NLL-Loss 112.5705, KL-Loss 17.9832, KL-Weight 0.3290
# TRAIN Batch 0300/1315, ELBO-Loss 85.2412, NLL-Loss 79.3501, KL-Loss 17.7006, KL-Weight 0.3328
# TRAIN Batch 0350/1315, ELBO-Loss 109.9328, NLL-Loss 104.1917, KL-Loss 17.0553, KL-Weight 0.3366
# TRAIN Batch 0400/1315, ELBO-Loss 99.5983, NLL-Loss 93.6517, KL-Loss 17.4687, KL-Weight 0.3404
# TRAIN Batch 0450/1315, ELBO-Loss 95.9867, NLL-Loss 89.9081, KL-Loss 17.6590, KL-Weight 0.3442
# TRAIN Batch 0500/1315, ELBO-Loss 98.1677, NLL-Loss 92.1772, KL-Loss 17.2129, KL-Weight 0.3480
# TRAIN Batch 0550/1315, ELBO-Loss 109.6115, NLL-Loss 102.6980, KL-Loss 19.6506, KL-Weight 0.3518
# TRAIN Batch 0600/1315, ELBO-Loss 96.5298, NLL-Loss 90.3135, KL-Loss 17.4796, KL-Weight 0.3556
# TRAIN Batch 0650/1315, ELBO-Loss 112.9737, NLL-Loss 106.4694, KL-Loss 18.0962, KL-Weight 0.3594
# TRAIN Batch 0700/1315, ELBO-Loss 105.9248, NLL-Loss 99.6576, KL-Loss 17.2540, KL-Weight 0.3632
# TRAIN Batch 0750/1315, ELBO-Loss 116.8642, NLL-Loss 109.8584, KL-Loss 19.0877, KL-Weight 0.3670
# TRAIN Batch 0800/1315, ELBO-Loss 106.2358, NLL-Loss 99.5853, KL-Loss 17.9340, KL-Weight 0.3708
# TRAIN Batch 0850/1315, ELBO-Loss 108.6951, NLL-Loss 102.6176, KL-Loss 16.2221, KL-Weight 0.3746
# TRAIN Batch 0900/1315, ELBO-Loss 102.5308, NLL-Loss 96.2146, KL-Loss 16.6901, KL-Weight 0.3784
# TRAIN Batch 0950/1315, ELBO-Loss 99.0983, NLL-Loss 92.5547, KL-Loss 17.1188, KL-Weight 0.3822
# TRAIN Batch 1000/1315, ELBO-Loss 107.9012, NLL-Loss 101.1980, KL-Loss 17.3639, KL-Weight 0.3860
# TRAIN Batch 1050/1315, ELBO-Loss 114.4971, NLL-Loss 107.9474, KL-Loss 16.8006, KL-Weight 0.3898
# TRAIN Batch 1100/1315, ELBO-Loss 107.3894, NLL-Loss 100.6297, KL-Loss 17.1718, KL-Weight 0.3937
# TRAIN Batch 1150/1315, ELBO-Loss 128.1026, NLL-Loss 120.5307, KL-Loss 19.0512, KL-Weight 0.3975
# TRAIN Batch 1200/1315, ELBO-Loss 89.0863, NLL-Loss 82.1077, KL-Loss 17.3919, KL-Weight 0.4013
# TRAIN Batch 1250/1315, ELBO-Loss 114.9805, NLL-Loss 108.2912, KL-Loss 16.5146, KL-Weight 0.4051
# TRAIN Batch 1300/1315, ELBO-Loss 101.0362, NLL-Loss 94.1808, KL-Loss 16.7671, KL-Weight 0.4089
# TRAIN Batch 1314/1315, ELBO-Loss 103.3391, NLL-Loss 96.2923, KL-Loss 17.1906, KL-Weight 0.4099
# TRAIN Epoch 03/20, ELBO 105.8742, NLL 99.4815, KL 17.8031, PPL 111.6499
# VALID Epoch 03/20, ELBO 106.7992, NLL 99.8728, KL 16.8935, PPL 119.2860
# TEST Epoch 03/20, ELBO 106.1259, NLL 99.1631, KL 16.9825, PPL 114.5234
# Model saved at linear/E03.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 96.6634, NLL-Loss 89.6339, KL-Loss 17.1449, KL-Weight 0.4100
# TRAIN Batch 0050/1315, ELBO-Loss 93.6139, NLL-Loss 86.4489, KL-Loss 17.3151, KL-Weight 0.4138
# TRAIN Batch 0100/1315, ELBO-Loss 90.4864, NLL-Loss 83.7359, KL-Loss 16.1649, KL-Weight 0.4176
# TRAIN Batch 0150/1315, ELBO-Loss 98.9644, NLL-Loss 90.8842, KL-Loss 19.1743, KL-Weight 0.4214
# TRAIN Batch 0200/1315, ELBO-Loss 103.3822, NLL-Loss 95.8352, KL-Loss 17.7489, KL-Weight 0.4252
# TRAIN Batch 0250/1315, ELBO-Loss 104.5602, NLL-Loss 97.3736, KL-Loss 16.7517, KL-Weight 0.4290
# TRAIN Batch 0300/1315, ELBO-Loss 105.1827, NLL-Loss 97.7841, KL-Loss 17.0942, KL-Weight 0.4328
# TRAIN Batch 0350/1315, ELBO-Loss 112.0298, NLL-Loss 104.6634, KL-Loss 16.8715, KL-Weight 0.4366
# TRAIN Batch 0400/1315, ELBO-Loss 99.2209, NLL-Loss 91.9904, KL-Loss 16.4175, KL-Weight 0.4404
# TRAIN Batch 0450/1315, ELBO-Loss 112.0116, NLL-Loss 104.1441, KL-Loss 17.7109, KL-Weight 0.4442
# TRAIN Batch 0500/1315, ELBO-Loss 98.3031, NLL-Loss 91.4539, KL-Loss 15.2876, KL-Weight 0.4480
# TRAIN Batch 0550/1315, ELBO-Loss 109.9945, NLL-Loss 101.6537, KL-Loss 18.4602, KL-Weight 0.4518
# TRAIN Batch 0600/1315, ELBO-Loss 105.0422, NLL-Loss 97.3288, KL-Loss 16.9292, KL-Weight 0.4556
# TRAIN Batch 0650/1315, ELBO-Loss 96.2035, NLL-Loss 88.8124, KL-Loss 16.0874, KL-Weight 0.4594
# TRAIN Batch 0700/1315, ELBO-Loss 96.4560, NLL-Loss 89.2453, KL-Loss 15.5662, KL-Weight 0.4632
# TRAIN Batch 0750/1315, ELBO-Loss 113.3583, NLL-Loss 106.1168, KL-Loss 15.5053, KL-Weight 0.4670
# TRAIN Batch 0800/1315, ELBO-Loss 97.8504, NLL-Loss 90.4298, KL-Loss 15.7604, KL-Weight 0.4708
# TRAIN Batch 0850/1315, ELBO-Loss 102.9126, NLL-Loss 95.7632, KL-Loss 15.0628, KL-Weight 0.4746
# TRAIN Batch 0900/1315, ELBO-Loss 99.8547, NLL-Loss 92.4194, KL-Loss 15.5406, KL-Weight 0.4784
# TRAIN Batch 0950/1315, ELBO-Loss 100.7118, NLL-Loss 92.5982, KL-Loss 16.8246, KL-Weight 0.4822
# TRAIN Batch 1000/1315, ELBO-Loss 91.2021, NLL-Loss 83.5906, KL-Loss 15.6601, KL-Weight 0.4860
# TRAIN Batch 1050/1315, ELBO-Loss 109.7715, NLL-Loss 101.8310, KL-Loss 16.2102, KL-Weight 0.4898
# TRAIN Batch 1100/1315, ELBO-Loss 101.2430, NLL-Loss 93.8531, KL-Loss 14.9701, KL-Weight 0.4937
# TRAIN Batch 1150/1315, ELBO-Loss 105.1825, NLL-Loss 97.9107, KL-Loss 14.6180, KL-Weight 0.4975
# TRAIN Batch 1200/1315, ELBO-Loss 106.2080, NLL-Loss 98.6012, KL-Loss 15.1754, KL-Weight 0.5013
# TRAIN Batch 1250/1315, ELBO-Loss 107.8872, NLL-Loss 100.1068, KL-Loss 15.4051, KL-Weight 0.5051
# TRAIN Batch 1300/1315, ELBO-Loss 91.9820, NLL-Loss 84.8454, KL-Loss 14.0246, KL-Weight 0.5089
# TRAIN Batch 1314/1315, ELBO-Loss 120.6537, NLL-Loss 112.5677, KL-Loss 15.8572, KL-Weight 0.5099
# TRAIN Epoch 04/20, ELBO 104.1754, NLL 96.7630, KL 16.1527, PPL 98.1516
# VALID Epoch 04/20, ELBO 107.0592, NLL 99.3821, KL 15.0531, PPL 116.5162
# TEST Epoch 04/20, ELBO 106.1788, NLL 98.4450, KL 15.1643, PPL 110.6584
# Model saved at linear/E04.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 92.5742, NLL-Loss 84.8096, KL-Loss 15.2248, KL-Weight 0.5100
# TRAIN Batch 0050/1315, ELBO-Loss 91.7164, NLL-Loss 83.5545, KL-Loss 15.8852, KL-Weight 0.5138
# TRAIN Batch 0100/1315, ELBO-Loss 109.5461, NLL-Loss 101.1776, KL-Loss 16.1678, KL-Weight 0.5176
# TRAIN Batch 0150/1315, ELBO-Loss 92.4589, NLL-Loss 84.7364, KL-Loss 14.8109, KL-Weight 0.5214
# TRAIN Batch 0200/1315, ELBO-Loss 106.8284, NLL-Loss 99.0263, KL-Loss 14.8551, KL-Weight 0.5252
# TRAIN Batch 0250/1315, ELBO-Loss 117.8252, NLL-Loss 109.1016, KL-Loss 16.4904, KL-Weight 0.5290
# TRAIN Batch 0300/1315, ELBO-Loss 99.8726, NLL-Loss 92.2338, KL-Loss 14.3367, KL-Weight 0.5328
# TRAIN Batch 0350/1315, ELBO-Loss 104.4751, NLL-Loss 96.2655, KL-Loss 15.2988, KL-Weight 0.5366
# TRAIN Batch 0400/1315, ELBO-Loss 108.4247, NLL-Loss 100.6143, KL-Loss 14.4524, KL-Weight 0.5404
# TRAIN Batch 0450/1315, ELBO-Loss 105.9306, NLL-Loss 97.5428, KL-Loss 15.4124, KL-Weight 0.5442
# TRAIN Batch 0500/1315, ELBO-Loss 105.3601, NLL-Loss 97.3668, KL-Loss 14.5857, KL-Weight 0.5480
# TRAIN Batch 0550/1315, ELBO-Loss 95.5007, NLL-Loss 87.5883, KL-Loss 14.3386, KL-Weight 0.5518
# TRAIN Batch 0600/1315, ELBO-Loss 93.8167, NLL-Loss 85.9970, KL-Loss 14.0736, KL-Weight 0.5556
# TRAIN Batch 0650/1315, ELBO-Loss 120.4248, NLL-Loss 111.1809, KL-Loss 16.5239, KL-Weight 0.5594
# TRAIN Batch 0700/1315, ELBO-Loss 109.6647, NLL-Loss 101.4566, KL-Loss 14.5734, KL-Weight 0.5632
# TRAIN Batch 0750/1315, ELBO-Loss 111.0453, NLL-Loss 102.2003, KL-Loss 15.5987, KL-Weight 0.5670
# TRAIN Batch 0800/1315, ELBO-Loss 95.6996, NLL-Loss 87.4897, KL-Loss 14.3822, KL-Weight 0.5708
# TRAIN Batch 0850/1315, ELBO-Loss 108.8764, NLL-Loss 100.0097, KL-Loss 15.4302, KL-Weight 0.5746
# TRAIN Batch 0900/1315, ELBO-Loss 108.3269, NLL-Loss 100.2230, KL-Loss 14.0098, KL-Weight 0.5784
# TRAIN Batch 0950/1315, ELBO-Loss 91.2654, NLL-Loss 83.4727, KL-Loss 13.3838, KL-Weight 0.5822
# TRAIN Batch 1000/1315, ELBO-Loss 95.2760, NLL-Loss 87.2969, KL-Loss 13.6153, KL-Weight 0.5860
# TRAIN Batch 1050/1315, ELBO-Loss 88.5741, NLL-Loss 81.0323, KL-Loss 12.7859, KL-Weight 0.5898
# TRAIN Batch 1100/1315, ELBO-Loss 101.4717, NLL-Loss 93.0684, KL-Loss 14.1553, KL-Weight 0.5937
# TRAIN Batch 1150/1315, ELBO-Loss 107.0929, NLL-Loss 98.7040, KL-Loss 14.0411, KL-Weight 0.5975
# TRAIN Batch 1200/1315, ELBO-Loss 94.6679, NLL-Loss 86.6183, KL-Loss 13.3880, KL-Weight 0.6013
# TRAIN Batch 1250/1315, ELBO-Loss 109.4023, NLL-Loss 101.2803, KL-Loss 13.4234, KL-Weight 0.6051
# TRAIN Batch 1300/1315, ELBO-Loss 96.9673, NLL-Loss 88.5865, KL-Loss 13.7647, KL-Weight 0.6089
# TRAIN Batch 1314/1315, ELBO-Loss 100.2158, NLL-Loss 91.6886, KL-Loss 13.9809, KL-Weight 0.6099
# TRAIN Epoch 05/20, ELBO 103.1583, NLL 95.0166, KL 14.5694, PPL 90.3538
# VALID Epoch 05/20, ELBO 107.5729, NLL 99.3730, KL 13.4425, PPL 116.4651
# TEST Epoch 05/20, ELBO 106.7880, NLL 98.5411, KL 13.5195, PPL 111.1679
# Model saved at linear/E05.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 109.0591, NLL-Loss 99.9837, KL-Loss 14.8777, KL-Weight 0.6100
# TRAIN Batch 0050/1315, ELBO-Loss 85.8707, NLL-Loss 77.7699, KL-Loss 13.1978, KL-Weight 0.6138
# TRAIN Batch 0100/1315, ELBO-Loss 101.9856, NLL-Loss 93.8156, KL-Loss 13.2286, KL-Weight 0.6176
# TRAIN Batch 0150/1315, ELBO-Loss 102.9727, NLL-Loss 94.7513, KL-Loss 13.2303, KL-Weight 0.6214
# TRAIN Batch 0200/1315, ELBO-Loss 88.8946, NLL-Loss 80.9752, KL-Loss 12.6667, KL-Weight 0.6252
# TRAIN Batch 0250/1315, ELBO-Loss 102.3014, NLL-Loss 93.8023, KL-Loss 13.5119, KL-Weight 0.6290
# TRAIN Batch 0300/1315, ELBO-Loss 97.8167, NLL-Loss 89.3146, KL-Loss 13.4353, KL-Weight 0.6328
# TRAIN Batch 0350/1315, ELBO-Loss 128.4949, NLL-Loss 119.2087, KL-Loss 14.5868, KL-Weight 0.6366
# TRAIN Batch 0400/1315, ELBO-Loss 96.9529, NLL-Loss 88.8248, KL-Loss 12.6917, KL-Weight 0.6404
# TRAIN Batch 0450/1315, ELBO-Loss 104.7493, NLL-Loss 95.7311, KL-Loss 13.9985, KL-Weight 0.6442
# TRAIN Batch 0500/1315, ELBO-Loss 93.3566, NLL-Loss 84.7149, KL-Loss 13.3355, KL-Weight 0.6480
# TRAIN Batch 0550/1315, ELBO-Loss 106.9659, NLL-Loss 98.1233, KL-Loss 13.5658, KL-Weight 0.6518
# TRAIN Batch 0600/1315, ELBO-Loss 116.2181, NLL-Loss 107.1861, KL-Loss 13.7762, KL-Weight 0.6556
# TRAIN Batch 0650/1315, ELBO-Loss 105.4161, NLL-Loss 96.7180, KL-Loss 13.1903, KL-Weight 0.6594
# TRAIN Batch 0700/1315, ELBO-Loss 104.9827, NLL-Loss 96.5583, KL-Loss 12.7019, KL-Weight 0.6632
# TRAIN Batch 0750/1315, ELBO-Loss 125.1543, NLL-Loss 115.6306, KL-Loss 14.2777, KL-Weight 0.6670
# TRAIN Batch 0800/1315, ELBO-Loss 111.3010, NLL-Loss 102.4395, KL-Loss 13.2096, KL-Weight 0.6708
# TRAIN Batch 0850/1315, ELBO-Loss 109.1210, NLL-Loss 100.8037, KL-Loss 12.3285, KL-Weight 0.6746
# TRAIN Batch 0900/1315, ELBO-Loss 92.9562, NLL-Loss 84.8551, KL-Loss 11.9407, KL-Weight 0.6784
# TRAIN Batch 0950/1315, ELBO-Loss 112.4402, NLL-Loss 103.4895, KL-Loss 13.1194, KL-Weight 0.6822
# TRAIN Batch 1000/1315, ELBO-Loss 106.9942, NLL-Loss 98.0674, KL-Loss 13.0120, KL-Weight 0.6860
# TRAIN Batch 1050/1315, ELBO-Loss 102.1004, NLL-Loss 93.4674, KL-Loss 12.5144, KL-Weight 0.6898
# TRAIN Batch 1100/1315, ELBO-Loss 106.3283, NLL-Loss 97.8726, KL-Loss 12.1901, KL-Weight 0.6937
# TRAIN Batch 1150/1315, ELBO-Loss 93.8323, NLL-Loss 85.9082, KL-Loss 11.3615, KL-Weight 0.6975
# TRAIN Batch 1200/1315, ELBO-Loss 102.3028, NLL-Loss 94.3997, KL-Loss 11.2700, KL-Weight 0.7013
# TRAIN Batch 1250/1315, ELBO-Loss 93.8789, NLL-Loss 85.3337, KL-Loss 12.1198, KL-Weight 0.7051
# TRAIN Batch 1300/1315, ELBO-Loss 87.7284, NLL-Loss 79.3778, KL-Loss 11.7803, KL-Weight 0.7089
# TRAIN Batch 1314/1315, ELBO-Loss 115.8104, NLL-Loss 106.8665, KL-Loss 12.5984, KL-Weight 0.7099
# TRAIN Epoch 06/20, ELBO 102.3224, NLL 93.7925, KL 12.9476, PPL 85.2604
# VALID Epoch 06/20, ELBO 108.0235, NLL 99.7237, KL 11.6899, PPL 118.4373
# TEST Epoch 06/20, ELBO 107.1838, NLL 98.8295, KL 11.7667, PPL 112.7113
# Model saved at linear/E06.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 100.4927, NLL-Loss 91.9518, KL-Loss 12.0294, KL-Weight 0.7100
# TRAIN Batch 0050/1315, ELBO-Loss 102.5226, NLL-Loss 93.4366, KL-Loss 12.7289, KL-Weight 0.7138
# TRAIN Batch 0100/1315, ELBO-Loss 92.7370, NLL-Loss 84.3607, KL-Loss 11.6726, KL-Weight 0.7176
# TRAIN Batch 0150/1315, ELBO-Loss 105.2200, NLL-Loss 96.0937, KL-Loss 12.6507, KL-Weight 0.7214
# TRAIN Batch 0200/1315, ELBO-Loss 104.4099, NLL-Loss 95.7291, KL-Loss 11.9701, KL-Weight 0.7252
# TRAIN Batch 0250/1315, ELBO-Loss 111.7518, NLL-Loss 102.5119, KL-Loss 12.6747, KL-Weight 0.7290
# TRAIN Batch 0300/1315, ELBO-Loss 88.5676, NLL-Loss 80.5870, KL-Loss 10.8904, KL-Weight 0.7328
# TRAIN Batch 0350/1315, ELBO-Loss 103.0896, NLL-Loss 94.5547, KL-Loss 11.5865, KL-Weight 0.7366
# TRAIN Batch 0400/1315, ELBO-Loss 114.6173, NLL-Loss 104.7724, KL-Loss 13.2964, KL-Weight 0.7404
# TRAIN Batch 0450/1315, ELBO-Loss 91.4408, NLL-Loss 82.9799, KL-Loss 11.3688, KL-Weight 0.7442
# TRAIN Batch 0500/1315, ELBO-Loss 105.0270, NLL-Loss 96.5577, KL-Loss 11.3223, KL-Weight 0.7480
# TRAIN Batch 0550/1315, ELBO-Loss 103.1518, NLL-Loss 93.7194, KL-Loss 12.5459, KL-Weight 0.7518
# TRAIN Batch 0600/1315, ELBO-Loss 92.2882, NLL-Loss 84.0010, KL-Loss 10.9673, KL-Weight 0.7556
# TRAIN Batch 0650/1315, ELBO-Loss 106.5502, NLL-Loss 97.9685, KL-Loss 11.3002, KL-Weight 0.7594
# TRAIN Batch 0700/1315, ELBO-Loss 113.2957, NLL-Loss 104.4592, KL-Loss 11.5777, KL-Weight 0.7632
# TRAIN Batch 0750/1315, ELBO-Loss 110.3425, NLL-Loss 101.3572, KL-Loss 11.7143, KL-Weight 0.7670
# TRAIN Batch 0800/1315, ELBO-Loss 101.6799, NLL-Loss 92.0921, KL-Loss 12.4381, KL-Weight 0.7708
# TRAIN Batch 0850/1315, ELBO-Loss 108.2033, NLL-Loss 99.6385, KL-Loss 11.0565, KL-Weight 0.7746
# TRAIN Batch 0900/1315, ELBO-Loss 93.3011, NLL-Loss 85.2563, KL-Loss 10.3345, KL-Weight 0.7784
# TRAIN Batch 0950/1315, ELBO-Loss 115.7393, NLL-Loss 107.0174, KL-Loss 11.1499, KL-Weight 0.7822
# TRAIN Batch 1000/1315, ELBO-Loss 101.4939, NLL-Loss 92.9150, KL-Loss 10.9141, KL-Weight 0.7860
# TRAIN Batch 1050/1315, ELBO-Loss 95.3159, NLL-Loss 86.9481, KL-Loss 10.5942, KL-Weight 0.7898
# TRAIN Batch 1100/1315, ELBO-Loss 109.7893, NLL-Loss 100.8621, KL-Loss 11.2483, KL-Weight 0.7937
# TRAIN Batch 1150/1315, ELBO-Loss 105.4352, NLL-Loss 97.3222, KL-Loss 10.1736, KL-Weight 0.7975
# TRAIN Batch 1200/1315, ELBO-Loss 108.0032, NLL-Loss 98.4324, KL-Loss 11.9447, KL-Weight 0.8013
# TRAIN Batch 1250/1315, ELBO-Loss 96.7280, NLL-Loss 88.1238, KL-Loss 10.6876, KL-Weight 0.8051
# TRAIN Batch 1300/1315, ELBO-Loss 92.6738, NLL-Loss 83.6389, KL-Loss 11.1699, KL-Weight 0.8089
# TRAIN Batch 1314/1315, ELBO-Loss 97.8429, NLL-Loss 88.9501, KL-Loss 10.9798, KL-Weight 0.8099
# TRAIN Epoch 07/20, ELBO 101.7538, NLL 93.1067, KL 11.3977, PPL 82.5336
# VALID Epoch 07/20, ELBO 108.9878, NLL 100.5562, KL 10.4093, PPL 123.2534
# TEST Epoch 07/20, ELBO 107.8892, NLL 99.4263, KL 10.4479, PPL 115.9738
# Model saved at linear/E07.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 95.3512, NLL-Loss 87.0441, KL-Loss 10.2557, KL-Weight 0.8100
# TRAIN Batch 0050/1315, ELBO-Loss 100.7508, NLL-Loss 91.6817, KL-Loss 11.1441, KL-Weight 0.8138
# TRAIN Batch 0100/1315, ELBO-Loss 110.3188, NLL-Loss 101.0344, KL-Loss 11.3555, KL-Weight 0.8176
# TRAIN Batch 0150/1315, ELBO-Loss 99.2247, NLL-Loss 90.5275, KL-Loss 10.5881, KL-Weight 0.8214
# TRAIN Batch 0200/1315, ELBO-Loss 103.3316, NLL-Loss 94.7424, KL-Loss 10.4084, KL-Weight 0.8252
# TRAIN Batch 0250/1315, ELBO-Loss 87.1581, NLL-Loss 78.9515, KL-Loss 9.8993, KL-Weight 0.8290
# TRAIN Batch 0300/1315, ELBO-Loss 101.3546, NLL-Loss 92.6011, KL-Loss 10.5107, KL-Weight 0.8328
# TRAIN Batch 0350/1315, ELBO-Loss 109.0632, NLL-Loss 100.2084, KL-Loss 10.5840, KL-Weight 0.8366
# TRAIN Batch 0400/1315, ELBO-Loss 105.4437, NLL-Loss 96.0399, KL-Loss 11.1895, KL-Weight 0.8404
# TRAIN Batch 0450/1315, ELBO-Loss 99.7550, NLL-Loss 91.0748, KL-Loss 10.2819, KL-Weight 0.8442
# TRAIN Batch 0500/1315, ELBO-Loss 97.8909, NLL-Loss 89.5323, KL-Loss 9.8566, KL-Weight 0.8480
# TRAIN Batch 0550/1315, ELBO-Loss 105.3073, NLL-Loss 95.9759, KL-Loss 10.9546, KL-Weight 0.8518
# TRAIN Batch 0600/1315, ELBO-Loss 89.3483, NLL-Loss 81.3046, KL-Loss 9.4010, KL-Weight 0.8556
# TRAIN Batch 0650/1315, ELBO-Loss 94.5417, NLL-Loss 86.0929, KL-Loss 9.8307, KL-Weight 0.8594
# TRAIN Batch 0700/1315, ELBO-Loss 85.0628, NLL-Loss 76.9267, KL-Loss 9.4252, KL-Weight 0.8632
# TRAIN Batch 0750/1315, ELBO-Loss 107.8511, NLL-Loss 99.3304, KL-Loss 9.8274, KL-Weight 0.8670
# TRAIN Batch 0800/1315, ELBO-Loss 109.7255, NLL-Loss 101.1848, KL-Loss 9.8074, KL-Weight 0.8708
# TRAIN Batch 0850/1315, ELBO-Loss 97.9090, NLL-Loss 89.9889, KL-Loss 9.0552, KL-Weight 0.8746
# TRAIN Batch 0900/1315, ELBO-Loss 78.9947, NLL-Loss 71.2359, KL-Loss 8.8324, KL-Weight 0.8784
# TRAIN Batch 0950/1315, ELBO-Loss 108.2362, NLL-Loss 99.3141, KL-Loss 10.1129, KL-Weight 0.8822
# TRAIN Batch 1000/1315, ELBO-Loss 94.5128, NLL-Loss 86.4979, KL-Loss 9.0457, KL-Weight 0.8860
# TRAIN Batch 1050/1315, ELBO-Loss 97.6941, NLL-Loss 89.2348, KL-Loss 9.5065, KL-Weight 0.8898
# TRAIN Batch 1100/1315, ELBO-Loss 114.7513, NLL-Loss 106.1464, KL-Loss 9.6290, KL-Weight 0.8937
# TRAIN Batch 1150/1315, ELBO-Loss 113.6104, NLL-Loss 104.5460, KL-Loss 10.1002, KL-Weight 0.8975
# TRAIN Batch 1200/1315, ELBO-Loss 103.1275, NLL-Loss 94.5682, KL-Loss 9.4970, KL-Weight 0.9013
# TRAIN Batch 1250/1315, ELBO-Loss 97.3329, NLL-Loss 89.0823, KL-Loss 9.1161, KL-Weight 0.9051
# TRAIN Batch 1300/1315, ELBO-Loss 103.9550, NLL-Loss 95.5714, KL-Loss 9.2243, KL-Weight 0.9089
# TRAIN Batch 1314/1315, ELBO-Loss 97.2793, NLL-Loss 89.4841, KL-Loss 8.5670, KL-Weight 0.9099
# TRAIN Epoch 08/20, ELBO 101.2020, NLL 92.6841, KL 9.9226, PPL 80.8967
# VALID Epoch 08/20, ELBO 109.2717, NLL 101.2204, KL 8.8476, PPL 127.2354
# TEST Epoch 08/20, ELBO 108.3136, NLL 100.2638, KL 8.8460, PPL 120.7111
# Model saved at linear/E08.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 128.5516, NLL-Loss 119.5076, KL-Loss 9.9384, KL-Weight 0.9100
# TRAIN Batch 0050/1315, ELBO-Loss 97.2640, NLL-Loss 89.2412, KL-Loss 8.7795, KL-Weight 0.9138
# TRAIN Batch 0100/1315, ELBO-Loss 90.1886, NLL-Loss 81.9220, KL-Loss 9.0090, KL-Weight 0.9176
# TRAIN Batch 0150/1315, ELBO-Loss 82.4595, NLL-Loss 75.2021, KL-Loss 7.8765, KL-Weight 0.9214
# TRAIN Batch 0200/1315, ELBO-Loss 92.0293, NLL-Loss 84.0404, KL-Loss 8.6347, KL-Weight 0.9252
# TRAIN Batch 0250/1315, ELBO-Loss 129.0977, NLL-Loss 119.8815, KL-Loss 9.9205, KL-Weight 0.9290
# TRAIN Batch 0300/1315, ELBO-Loss 100.1972, NLL-Loss 92.2085, KL-Loss 8.5641, KL-Weight 0.9328
# TRAIN Batch 0350/1315, ELBO-Loss 109.7353, NLL-Loss 101.2305, KL-Loss 9.0803, KL-Weight 0.9366
# TRAIN Batch 0400/1315, ELBO-Loss 83.7123, NLL-Loss 76.3701, KL-Loss 7.8074, KL-Weight 0.9404
# TRAIN Batch 0450/1315, ELBO-Loss 95.3726, NLL-Loss 86.8243, KL-Loss 9.0533, KL-Weight 0.9442
# TRAIN Batch 0500/1315, ELBO-Loss 97.9110, NLL-Loss 89.8732, KL-Loss 8.4786, KL-Weight 0.9480
# TRAIN Batch 0550/1315, ELBO-Loss 91.6803, NLL-Loss 83.4326, KL-Loss 8.6651, KL-Weight 0.9518
# TRAIN Batch 0600/1315, ELBO-Loss 100.6316, NLL-Loss 92.8735, KL-Loss 8.1184, KL-Weight 0.9556
# TRAIN Batch 0650/1315, ELBO-Loss 110.7042, NLL-Loss 101.8870, KL-Loss 9.1901, KL-Weight 0.9594
# TRAIN Batch 0700/1315, ELBO-Loss 97.5275, NLL-Loss 89.5095, KL-Loss 8.3240, KL-Weight 0.9632
# TRAIN Batch 0750/1315, ELBO-Loss 93.4773, NLL-Loss 85.8556, KL-Loss 7.8816, KL-Weight 0.9670
# TRAIN Batch 0800/1315, ELBO-Loss 95.5933, NLL-Loss 88.1048, KL-Loss 7.7134, KL-Weight 0.9708
# TRAIN Batch 0850/1315, ELBO-Loss 107.9718, NLL-Loss 99.9942, KL-Loss 8.1852, KL-Weight 0.9746
# TRAIN Batch 0900/1315, ELBO-Loss 95.5362, NLL-Loss 87.8411, KL-Loss 7.8646, KL-Weight 0.9784
# TRAIN Batch 0950/1315, ELBO-Loss 102.2418, NLL-Loss 93.9277, KL-Loss 8.4644, KL-Weight 0.9822
# TRAIN Batch 1000/1315, ELBO-Loss 120.9589, NLL-Loss 112.1372, KL-Loss 8.9465, KL-Weight 0.9860
# TRAIN Batch 1050/1315, ELBO-Loss 95.8659, NLL-Loss 88.1753, KL-Loss 7.7695, KL-Weight 0.9898
# TRAIN Batch 1100/1315, ELBO-Loss 120.3897, NLL-Loss 111.4683, KL-Loss 8.9783, KL-Weight 0.9937
# TRAIN Batch 1150/1315, ELBO-Loss 91.1353, NLL-Loss 84.2411, KL-Loss 6.9118, KL-Weight 0.9975
# TRAIN Batch 1200/1315, ELBO-Loss 89.4594, NLL-Loss 82.2896, KL-Loss 7.1699, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 108.5925, NLL-Loss 100.6769, KL-Loss 7.9156, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 121.0915, NLL-Loss 113.0364, KL-Loss 8.0551, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss
KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 107.6627, NLL-Loss 100.1194, KL-Loss 7.5433, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 93.0082, NLL-Loss 85.6557, KL-Loss 7.3524, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 116.0863, NLL-Loss 108.0077, KL-Loss 8.0785, KL-Weight 1.0000
# TRAIN Epoch 12/20, ELBO 96.1963, NLL 88.5953, KL 7.6010, PPL 66.6441
# VALID Epoch 12/20, ELBO 108.6577, NLL 101.4026, KL 7.2552, PPL 128.3500
# TEST Epoch 12/20, ELBO 107.2687, NLL 99.9980, KL 7.2707, PPL 119.1870
# Model saved at linear/E12.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 83.1277, NLL-Loss 76.4015, KL-Loss 6.7262, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 90.4021, NLL-Loss 82.5136, KL-Loss 7.8885, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 94.0307, NLL-Loss 86.4954, KL-Loss 7.5353, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 97.8796, NLL-Loss 90.0760, KL-Loss 7.8035, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 100.8600, NLL-Loss 93.2082, KL-Loss 7.6517, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 104.0435, NLL-Loss 96.1837, KL-Loss 7.8597, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 80.5843, NLL-Loss 73.4101, KL-Loss 7.1742, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss 93.3163, NLL-Loss 85.9130, KL-Loss 7.4033, KL-Weight 1.0000
# TRAIN Batch 0400/1315, ELBO-Loss 98.1026, NLL-Loss 90.3506, KL-Loss 7.7520, KL-Weight 1.0000
# TRAIN Batch 0450/1315, ELBO-Loss 78.4312, NLL-Loss 71.1141, KL-Loss 7.3171, KL-Weight 1.0000
# TRAIN Batch 0500/1315, ELBO-Loss 102.7015, NLL-Loss 94.7864, KL-Loss 7.9151, KL-Weight 1.0000
# TRAIN Batch 0550/1315, ELBO-Loss 85.5397, NLL-Loss 78.3581, KL-Loss 7.1815, KL-Weight 1.0000
# TRAIN Batch 0600/1315, ELBO-Loss 100.5045, NLL-Loss 93.1758, KL-Loss 7.3288, KL-Weight 1.0000
# TRAIN Batch 0650/1315, ELBO-Loss 93.1106, NLL-Loss 85.8016, KL-Loss 7.3090, KL-Weight 1.0000
# TRAIN Batch 0700/1315, ELBO-Loss 100.7574, NLL-Loss 92.3880, KL-Loss 8.3694, KL-Weight 1.0000
# TRAIN Batch 0750/1315, ELBO-Loss 109.3167, NLL-Loss 101.5699, KL-Loss 7.7468, KL-Weight 1.0000
# TRAIN Batch 0800/1315, ELBO-Loss 88.3496, NLL-Loss 80.7105, KL-Loss 7.6392, KL-Weight 1.0000
# TRAIN Batch 0850/1315, ELBO-Loss 105.2699, NLL-Loss 97.1318, KL-Loss 8.1382, KL-Weight 1.0000
# TRAIN Batch 0900/1315, ELBO-Loss 95.5347, NLL-Loss 88.1709, KL-Loss 7.3638, KL-Weight 1.0000
# TRAIN Batch 0950/1315, ELBO-Loss 89.3444, NLL-Loss 81.9425, KL-Loss 7.4019, KL-Weight 1.0000
# TRAIN Batch 1000/1315, ELBO-Loss 84.3281, NLL-Loss 77.7730, KL-Loss 6.5552, KL-Weight 1.0000
# TRAIN Batch 1050/1315, ELBO-Loss 104.3763, NLL-Loss 96.0304, KL-Loss 8.3459, KL-Weight 1.0000
# TRAIN Batch 1100/1315, ELBO-Loss 83.7215, NLL-Loss 76.4230, KL-Loss 7.2984, KL-Weight 1.0000
# TRAIN Batch 1150/1315, ELBO-Loss 84.3015, NLL-Loss 77.0448, KL-Loss 7.2568, KL-Weight 1.0000
# TRAIN Batch 1200/1315, ELBO-Loss 90.7548, NLL-Loss 83.4974, KL-Loss 7.2573, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 96.9734, NLL-Loss 89.6739, KL-Loss 7.2995, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 101.2357, NLL-Loss 93.1891, KL-Loss 8.0466, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 98.0929, NLL-Loss 90.6028, KL-Loss 7.4901, KL-Weight 1.0000
# TRAIN Epoch 13/20, ELBO 95.6715, NLL 88.0910, KL 7.5805, PPL 65.0699
# VALID Epoch 13/20, ELBO 108.6833, NLL 101.3689, KL 7.3144, PPL 128.1432
# TEST Epoch 13/20, ELBO 107.2406, NLL 99.8919, KL 7.3487, PPL 118.5840
# Model saved at linear/E13.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 96.4653, NLL-Loss 89.0840, KL-Loss 7.3813, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 107.0242, NLL-Loss 98.5284, KL-Loss 8.4958, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 84.9348, NLL-Loss 77.0041, KL-Loss 7.9308, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 83.4684, NLL-Loss 76.2851, KL-Loss 7.1833, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 84.4498, NLL-Loss 77.0901, KL-Loss 7.3597, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 104.6059, NLL-Loss 96.6109, KL-Loss 7.9951, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 103.7878, NLL-Loss 96.2571, KL-Loss 7.5307, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss
KL-Weight 1.0000
# TRAIN Batch 1000/1315, ELBO-Loss 99.6365, NLL-Loss 91.5365, KL-Loss 8.1001, KL-Weight 1.0000
# TRAIN Batch 1050/1315, ELBO-Loss 88.2902, NLL-Loss 80.5786, KL-Loss 7.7116, KL-Weight 1.0000
# TRAIN Batch 1100/1315, ELBO-Loss 93.1594, NLL-Loss 85.4906, KL-Loss 7.6688, KL-Weight 1.0000
# TRAIN Batch 1150/1315, ELBO-Loss 98.4906, NLL-Loss 90.5947, KL-Loss 7.8959, KL-Weight 1.0000
# TRAIN Batch 1200/1315, ELBO-Loss 100.0487, NLL-Loss 91.5634, KL-Loss 8.4852, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 96.7962, NLL-Loss 89.1662, KL-Loss 7.6300, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 88.5899, NLL-Loss 81.3354, KL-Loss 7.2545, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 103.8397, NLL-Loss 95.3173, KL-Loss 8.5223, KL-Weight 1.0000
# TRAIN Epoch 18/20, ELBO 94.1568, NLL 86.5206, KL 7.6362, PPL 60.4024
# VALID Epoch 18/20, ELBO 108.5348, NLL 101.2169, KL 7.3179, PPL 127.2144
# TEST Epoch 18/20, ELBO 107.0045, NLL 99.6675, KL 7.3370, PPL 117.3188
# Model saved at linear/E18.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 104.5803, NLL-Loss 96.2993, KL-Loss 8.2809, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 90.0289, NLL-Loss 82.5828, KL-Loss 7.4461, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 85.0584, NLL-Loss 78.1331, KL-Loss 6.9252, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 91.1637, NLL-Loss 83.5431, KL-Loss 7.6205, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 87.0886, NLL-Loss 80.2815, KL-Loss 6.8071, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 81.4123, NLL-Loss 74.1131, KL-Loss 7.2993, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 87.9400, NLL-Loss 80.6444, KL-Loss 7.2956, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss 81.0012, NLL-Loss 73.8794, KL-Loss 7.1217, KL-Weight 1.0000
# TRAIN Batch 0400/1315, ELBO-Loss 87.6947, NLL-Loss 80.6013, KL-Loss 7.0934, KL-Weight 1.0000
# TRAIN Batch 0450/1315, ELBO-Loss 87.7149, NLL-Loss 80.1737, KL-Loss 7.5412, KL-Weight 1.0000
# TRAIN Batch 0500/1315, ELBO-Loss 98.0494, NLL-Loss 90.2340, KL-Loss 7.8153, KL-Weight 1.0000
# TRAIN Batch 0550/1315, ELBO-Loss 95.9585, NLL-Loss 87.7233, KL-Loss 8.2352, KL-Weight 1.0000
# TRAIN Batch 0600/1315, ELBO-Loss 96.0437, NLL-Loss 88.3465, KL-Loss 7.6973, KL-Weight 1.0000
# TRAIN Batch 0650/1315, ELBO-Loss 91.3473, NLL-Loss 83.5553, KL-Loss 7.7919, KL-Weight 1.0000
# TRAIN Batch 0700/1315, ELBO-Loss 87.7476, NLL-Loss 79.8250, KL-Loss 7.9226, KL-Weight 1.0000
# TRAIN Batch 0750/1315, ELBO-Loss 91.7314, NLL-Loss 84.2947, KL-Loss 7.4367, KL-Weight 1.0000
# TRAIN Batch 0800/1315, ELBO-Loss 85.4073, NLL-Loss 78.3291, KL-Loss 7.0782, KL-Weight 1.0000
# TRAIN Batch 0850/1315, ELBO-Loss 102.6056, NLL-Loss 94.6471, KL-Loss 7.9585, KL-Weight 1.0000
# TRAIN Batch 0900/1315, ELBO-Loss 89.6101, NLL-Loss 82.6898, KL-Loss 6.9203, KL-Weight 1.0000
# TRAIN Batch 0950/1315, ELBO-Loss 91.0700, NLL-Loss 83.4394, KL-Loss 7.6306, KL-Weight 1.0000
# TRAIN Batch 1000/1315, ELBO-Loss 95.4002, NLL-Loss 87.5347, KL-Loss 7.8655, KL-Weight 1.0000
# TRAIN Batch 1050/1315, ELBO-Loss 95.2121, NLL-Loss 87.6892, KL-Loss 7.5228, KL-Weight 1.0000
# TRAIN Batch 1100/1315, ELBO-Loss 89.1611, NLL-Loss 81.9160, KL-Loss 7.2452, KL-Weight 1.0000
# TRAIN Batch 1150/1315, ELBO-Loss 91.0604, NLL-Loss 83.7484, KL-Loss 7.3120, KL-Weight 1.0000
# TRAIN Batch 1200/1315, ELBO-Loss 94.0086, NLL-Loss 86.6196, KL-Loss 7.3890, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 101.2964, NLL-Loss 93.8191, KL-Loss 7.4773, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 109.5930, NLL-Loss 101.5104, KL-Loss 8.0826, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 86.9650, NLL-Loss 79.7510, KL-Loss 7.2141, KL-Weight 1.0000
# TRAIN Epoch 19/20, ELBO 94.0692, NLL 86.4512, KL 7.6180, PPL 60.2039
# VALID Epoch 19/20, ELBO 108.5619, NLL 101.2267, KL 7.3352, PPL 127.2741
# TEST Epoch 19/20, ELBO 106.9401, NLL 99.5795, KL 7.3606, PPL 116.8260
# Model saved at linear/E19.pkl
#
# Total cost time 00 hr 13 min 16 sec

# %%
# plot KL curve
fig, ax1 = plt.subplots()
lns1 = ax1.plot(tracker['KL_weight'], 'b', label='KL term weight')
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('Step')
ax1.set_ylabel('KL term weight')
ax2 = ax1.twinx()
lns2 = ax2.plot(tracker['KL'], 'r', label='KL term value')
ax2.set_ylabel('KL term value')
lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, bbox_to_anchor=(0., 1.02, 1., .102),
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# latent space visualization
features = np.empty([len(datasets['test']), latent_dim])
for itr, (enc_inputs, dec_inputs, _, lengths) in enumerate(dataloaders['test']):
    enc_inputs = enc_inputs.to(device)
    dec_inputs = dec_inputs.to(device)
    lengths = lengths.to(device)
    _, mu, _ = model(enc_inputs, dec_inputs, lengths)
    start, end = batch_size * itr, batch_size * (itr + 1)
    features[start:end] = mu.data.cpu().numpy()
#tsne_z = TSNE(n_components=2).fit_transform(features)
tsne_z = features
tracker['z'] = tsne_z

plt.figure()
plt.scatter(tsne_z[:, 0], tsne_z[:, 1], s=25, alpha=0.5)
plt.show()

# %%
# save learning results
sio.savemat("linear.mat", tracker)

# %%
latent_dim
# Out:
# 16
