# %%
import sys
sys.path.append('..')

# %%
import os
import time
import math
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from sklearn.manifold import TSNE
from multiprocessing import cpu_count

# %%
from duc import DUC
from linear.model import RNNVAE
from utils import linear_anneal, log_Normal_diag, log_Normal_standard

# %%
# device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
data_path = '../data'
max_len = 64
splits = ['train', 'valid', 'test']
datasets = {split: DUC(root=data_path, split=split) for split in splits}

# %%
len(datasets['train'].word_to_idx)
# Out:
# 6238

# %%
datasets['train'][0]
# Out:
# (array([  53,   62,  420, 4084,  106,  841,  115, 1955,   12, 2474, 2055,
#            8,    4,  343,    6,  470,    9,    4, 1581, 2448,   11,  151,
#         4015,   25, 4416,    4, 1751,    5,    4,    1,  876, 5308,    5,
#          872, 2842,   92,  477,  484,    8, 3239, 3979,   10,   51, 1380,
#            9, 3221, 1128,    6,  872,  823,   92,    7, 3881, 2181,    5,
#          402,    8, 4576,  676,    9,    4,  231,   19,    4]),
#  array([   2,   53,   62,  420, 4084,  106,  841,  115, 1955,   12, 2474,
#         2055,    8,    4,  343,    6,  470,    9,    4, 1581, 2448,   11,
#          151, 4015,   25, 4416,    4, 1751,    5,    4,    1,  876, 5308,
#            5,  872, 2842,   92,  477,  484,    8, 3239, 3979,   10,   51,
#         1380,    9, 3221, 1128,    6,  872,  823,   92,    7, 3881, 2181,
#            5,  402,    8, 4576,  676,    9,    4,  231,   19,    4]),
#  array([  53,   62,  420, 4084,  106,  841,  115, 1955,   12, 2474, 2055,
#            8,    4,  343,    6,  470,    9,    4, 1581, 2448,   11,  151,
#         4015,   25, 4416,    4, 1751,    5,    4,    1,  876, 5308,    5,
#          872, 2842,   92,  477,  484,    8, 3239, 3979,   10,   51, 1380,
#            9, 3221, 1128,    6,  872,  823,   92,    7, 3881, 2181,    5,
#          402,    8, 4576,  676,    9,    4,  231,   19,    4,    3]),
#  64)

# %%
# data loader
batch_size = 32
dataloaders = {split: DataLoader(datasets[split],
                                 batch_size=batch_size,
                                 shuffle=split=='train',
                                 num_workers=cpu_count(),
                                 pin_memory=torch.cuda.is_available())
                                 for split in splits}
symbols = datasets['train'].symbols

# %%
# RNNVAE model
embedding_size = 300
hidden_size = 256
latent_dim = 32
dropout_rate = 0.5
model = RNNVAE(vocab_size=datasets['train'].vocab_size,
               embed_size=embedding_size,
               time_step=max_len,
               hidden_size=hidden_size,
               z_dim=latent_dim,
               dropout_rate=dropout_rate,
               bos_idx=symbols['<bos>'],
               eos_idx=symbols['<eos>'],
               pad_idx=symbols['<pad>'])
model = model.to(device)

# %%
# folder to save model
save_path = 'linear'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
# objective function
learning_rate = 0.001
criterion = nn.NLLLoss(size_average=False, ignore_index=symbols['<pad>'])
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# negative log likelihood
def NLL(logp, target, length):
    target = target[:, :torch.max(length).item()].contiguous().view(-1)
    logp = logp.view(-1, logp.size(-1))
    return criterion(logp, target)

# KL divergence
def KL_div(mu, logvar):
    return -0.5 * torch.sum(1. + logvar - mu.pow(2) - logvar.exp())

# %%
# training setting
epoch = 20
print_every = 50

# %%
# training interface
step = 0
tracker = {'ELBO': [], 'NLL': [], 'KL': [], 'KL_weight': []}
start_time = time.time()
for ep in range(epoch):
    # learning rate decay
    if ep >= 10 and ep % 2 == 0:
        learning_rate = learning_rate * 0.5
        for param_group in optimizer.param_groups:
            param_group['lr'] = learning_rate

    for split in splits:
        dataloader = dataloaders[split]
        model.train() if split == 'train' else model.eval()
        totals = {'ELBO': 0., 'NLL': 0., 'KL': 0., 'words': 0}

        for itr, (enc_inputs, dec_inputs, targets, lengths) in enumerate(dataloader):
            bsize = enc_inputs.size(0)
            enc_inputs = enc_inputs.to(device)
            dec_inputs = dec_inputs.to(device)
            targets = targets.to(device)
            lengths = lengths.to(device)
            #print(lengths)
            
            # forward
            logp, z, mu, logvar = model(enc_inputs, dec_inputs, lengths)

            # calculate loss
            NLL_loss = NLL(logp, targets, lengths + 1)
            #KL_loss = KL_div(mu, logvar)
            
            log_p_z = log_Normal_standard(z, dim=1)
            log_q_z = log_Normal_diag(z, mu, logvar, dim=1)
            KL_loss = torch.sum(-(log_p_z - log_q_z))
            
            KL_weight = linear_anneal(step, len(dataloaders['train']) * 10)
            loss = (NLL_loss + KL_weight * KL_loss) / bsize

            # cumulate
            totals['ELBO'] += loss.item() * bsize
            totals['NLL'] += NLL_loss.item()
            totals['KL'] += KL_loss.item()
            totals['words'] += torch.sum(lengths).item()

            # backward and optimize
            if split == 'train':
                step += 1
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), 5)
                optimizer.step()

                # track
                tracker['ELBO'].append(loss.item())
                tracker['NLL'].append(NLL_loss.item() / bsize)
                tracker['KL'].append(KL_loss.item() / bsize)
                tracker['KL_weight'].append(KL_weight)

                if(True):
                    # print statistics
                    if itr % print_every == 0 or itr + 1 == len(dataloader):
                        print("%s Batch %04d/%04d, ELBO-Loss %.4f, "
                              "NLL-Loss %.4f, KL-Loss %.4f, KL-Weight %.4f"
                              % (split.upper(), itr, len(dataloader),
                                 tracker['ELBO'][-1], tracker['NLL'][-1],
                                 tracker['KL'][-1], tracker['KL_weight'][-1]))

        samples = len(datasets[split])
        print("%s Epoch %02d/%02d, ELBO %.4f, NLL %.4f, KL %.4f, PPL %.4f"
              % (split.upper(), ep, epoch, totals['ELBO'] / samples,
                 totals['NLL'] / samples, totals['KL'] / samples,
                 math.exp(totals['NLL'] / totals['words'])))
    
    print('\n')
    # save checkpoint
    #checkpoint_path = os.path.join(save_path, "E%02d.pkl" % ep)
    #torch.save(model.state_dict(), checkpoint_path)
    #print("Model saved at %s\n" % checkpoint_path)
end_time = time.time()
print('Total cost time',
      time.strftime("%H hr %M min %S sec", time.gmtime(end_time - start_time)))
# Out:
# TRAIN Batch 0000/0370, ELBO-Loss 303.9259, NLL-Loss 303.9189, KL-Loss 0.6976, KL-Weight 0.0100
# TRAIN Batch 0050/0370, ELBO-Loss 319.6364, NLL-Loss 319.6114, KL-Loss 1.0626, KL-Weight 0.0235
# TRAIN Batch 0100/0370, ELBO-Loss 228.1291, NLL-Loss 227.7419, KL-Loss 10.4568, KL-Weight 0.0370
# TRAIN Batch 0150/0370, ELBO-Loss 204.9001, NLL-Loss 204.7030, KL-Loss 3.9002, KL-Weight 0.0505
# TRAIN Batch 0200/0370, ELBO-Loss 265.2679, NLL-Loss 265.0873, KL-Loss 2.8189, KL-Weight 0.0641
# TRAIN Batch 0250/0370, ELBO-Loss 237.6937, NLL-Loss 237.4530, KL-Loss 3.1025, KL-Weight 0.0776
# TRAIN Batch 0300/0370, ELBO-Loss 257.6044, NLL-Loss 257.4359, KL-Loss 1.8503, KL-Weight 0.0911
# TRAIN Batch 0350/0370, ELBO-Loss 231.0454, NLL-Loss 230.8821, KL-Loss 1.5614, KL-Weight 0.1046
# TRAIN Batch 0369/0370, ELBO-Loss 237.0620, NLL-Loss 236.8750, KL-Loss 1.7037, KL-Weight 0.1097
# TRAIN Epoch 00/20, ELBO 245.6943, NLL 245.4920, KL 3.9905, PPL 1287.8934
# VALID Epoch 00/20, ELBO 227.5739, NLL 227.4385, KL 1.2315, PPL 717.3424
# TEST Epoch 00/20, ELBO 220.3802, NLL 220.2330, KL 1.3382, PPL 713.9940
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 206.3738, NLL-Loss 206.2614, KL-Loss 1.0227, KL-Weight 0.1100
# TRAIN Batch 0050/0370, ELBO-Loss 232.5706, NLL-Loss 232.3667, KL-Loss 1.6513, KL-Weight 0.1235
# TRAIN Batch 0100/0370, ELBO-Loss 210.0730, NLL-Loss 209.9576, KL-Loss 0.8424, KL-Weight 0.1370
# TRAIN Batch 0150/0370, ELBO-Loss 245.5271, NLL-Loss 245.3673, KL-Loss 1.0615, KL-Weight 0.1505
# TRAIN Batch 0200/0370, ELBO-Loss 230.5418, NLL-Loss 230.4037, KL-Loss 0.8417, KL-Weight 0.1641
# TRAIN Batch 0250/0370, ELBO-Loss 221.4138, NLL-Loss 221.3149, KL-Loss 0.5569, KL-Weight 0.1776
# TRAIN Batch 0300/0370, ELBO-Loss 225.3735, NLL-Loss 225.3029, KL-Loss 0.3694, KL-Weight 0.1911
# TRAIN Batch 0350/0370, ELBO-Loss 232.1162, NLL-Loss 232.0687, KL-Loss 0.2322, KL-Weight 0.2046
# TRAIN Batch 0369/0370, ELBO-Loss 196.1510, NLL-Loss 196.1215, KL-Loss 0.1406, KL-Weight 0.2097
# TRAIN Epoch 01/20, ELBO 227.4864, NLL 227.3740, KL 0.7786, PPL 759.2106
# VALID Epoch 01/20, ELBO 224.1694, NLL 224.1277, KL 0.1982, PPL 651.8640
# TEST Epoch 01/20, ELBO 216.9631, NLL 216.9291, KL 0.1621, PPL 646.9686
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 221.2352, NLL-Loss 221.1708, KL-Loss 0.3067, KL-Weight 0.2100
# TRAIN Batch 0050/0370, ELBO-Loss 227.9675, NLL-Loss 227.8979, KL-Loss 0.3110, KL-Weight 0.2235
# TRAIN Batch 0100/0370, ELBO-Loss 194.4191, NLL-Loss 194.3700, KL-Loss 0.2074, KL-Weight 0.2370
# TRAIN Batch 0150/0370, ELBO-Loss 235.8145, NLL-Loss 235.7738, KL-Loss 0.1626, KL-Weight 0.2505
# TRAIN Batch 0200/0370, ELBO-Loss 217.8546, NLL-Loss 217.8316, KL-Loss 0.0869, KL-Weight 0.2641
# TRAIN Batch 0250/0370, ELBO-Loss 220.0693, NLL-Loss 220.0368, KL-Loss 0.1170, KL-Weight 0.2776
# TRAIN Batch 0300/0370, ELBO-Loss 202.8862, NLL-Loss 202.8657, KL-Loss 0.0706, KL-Weight 0.2911
# TRAIN Batch 0350/0370, ELBO-Loss 232.3400, NLL-Loss 232.3387, KL-Loss 0.0040, KL-Weight 0.3046
# TRAIN Batch 0369/0370, ELBO-Loss 279.3693, NLL-Loss 279.3809, KL-Loss -0.0374, KL-Weight 0.3097
# TRAIN Epoch 02/20, ELBO 224.0371, NLL 224.0142, KL 0.0920, PPL 688.3367
# VALID Epoch 02/20, ELBO 220.4578, NLL 220.4366, KL 0.0687, PPL 585.8822
# TEST Epoch 02/20, ELBO 213.3055, NLL 213.2878, KL 0.0568, PPL 580.3655
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 227.2815, NLL-Loss 227.2730, KL-Loss 0.0272, KL-Weight 0.3100
# TRAIN Batch 0050/0370, ELBO-Loss 223.9788, NLL-Loss 223.9614, KL-Loss 0.0537, KL-Weight 0.3235
# TRAIN Batch 0100/0370, ELBO-Loss 237.3201, NLL-Loss 237.3144, KL-Loss 0.0170, KL-Weight 0.3370
# TRAIN Batch 0150/0370, ELBO-Loss 222.1338, NLL-Loss 222.0898, KL-Loss 0.1253, KL-Weight 0.3505
# TRAIN Batch 0200/0370, ELBO-Loss 195.5545, NLL-Loss 195.5416, KL-Loss 0.0355, KL-Weight 0.3641
# TRAIN Batch 0250/0370, ELBO-Loss 200.3065, NLL-Loss 200.2920, KL-Loss 0.0383, KL-Weight 0.3776
# TRAIN Batch 0300/0370, ELBO-Loss 238.3087, NLL-Loss 238.2852, KL-Loss 0.0600, KL-Weight 0.3911
# TRAIN Batch 0350/0370, ELBO-Loss 233.1789, NLL-Loss 233.1688, KL-Loss 0.0248, KL-Weight 0.4046
# TRAIN Batch 0369/0370, ELBO-Loss 236.8009, NLL-Loss 236.7945, KL-Loss 0.0156, KL-Weight 0.4097
# TRAIN Epoch 03/20, ELBO 220.8993, NLL 220.8835, KL 0.0444, PPL 628.2626
# VALID Epoch 03/20, ELBO 217.4715, NLL 217.4653, KL 0.0150, PPL 537.6545
# TEST Epoch 03/20, ELBO 210.4441, NLL 210.4305, KL 0.0331, PPL 532.9392
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 204.7078, NLL-Loss 204.6884, KL-Loss 0.0474, KL-Weight 0.4100
# TRAIN Batch 0050/0370, ELBO-Loss 231.1243, NLL-Loss 231.1170, KL-Loss 0.0171, KL-Weight 0.4235
# TRAIN Batch 0100/0370, ELBO-Loss 246.1886, NLL-Loss 246.1756, KL-Loss 0.0298, KL-Weight 0.4370
# TRAIN Batch 0150/0370, ELBO-Loss 203.9915, NLL-Loss 204.0046, KL-Loss -0.0289, KL-Weight 0.4505
# TRAIN Batch 0200/0370, ELBO-Loss 232.0860, NLL-Loss 232.0606, KL-Loss 0.0548, KL-Weight 0.4641
# TRAIN Batch 0250/0370, ELBO-Loss 189.0621, NLL-Loss 189.0667, KL-Loss -0.0095, KL-Weight 0.4776
# TRAIN Batch 0300/0370, ELBO-Loss 249.5823, NLL-Loss 249.5307, KL-Loss 0.1050, KL-Weight 0.4911
# TRAIN Batch 0350/0370, ELBO-Loss 200.5037, NLL-Loss 200.4645, KL-Loss 0.0776, KL-Weight 0.5046
# TRAIN Batch 0369/0370, ELBO-Loss 262.4499, NLL-Loss 262.4133, KL-Loss 0.0717, KL-Weight 0.5097
# TRAIN Epoch 04/20, ELBO 218.2694, NLL 218.2550, KL 0.0318, PPL 581.8926
# VALID Epoch 04/20, ELBO 215.0409, NLL 215.0297, KL 0.0221, PPL 501.0962
# TEST Epoch 04/20, ELBO 208.1226, NLL 208.1088, KL 0.0270, PPL 497.2718
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 212.4515, NLL-Loss 212.4491, KL-Loss 0.0048, KL-Weight 0.5100
# TRAIN Batch 0050/0370, ELBO-Loss 212.2863, NLL-Loss 212.2585, KL-Loss 0.0531, KL-Weight 0.5235
# TRAIN Batch 0100/0370, ELBO-Loss 224.3038, NLL-Loss 224.2628, KL-Loss 0.0765, KL-Weight 0.5370
# TRAIN Batch 0150/0370, ELBO-Loss 221.3617, NLL-Loss 221.3281, KL-Loss 0.0610, KL-Weight 0.5505
# TRAIN Batch 0200/0370, ELBO-Loss 201.8001, NLL-Loss 201.7729, KL-Loss 0.0482, KL-Weight 0.5641
# TRAIN Batch 0250/0370, ELBO-Loss 205.2524, NLL-Loss 205.2244, KL-Loss 0.0485, KL-Weight 0.5776
# TRAIN Batch 0300/0370, ELBO-Loss 224.7737, NLL-Loss 224.7643, KL-Loss 0.0159, KL-Weight 0.5911
# TRAIN Batch 0350/0370, ELBO-Loss 210.9999, NLL-Loss 210.9489, KL-Loss 0.0843, KL-Weight 0.6046
# TRAIN Batch 0369/0370, ELBO-Loss 186.5267, NLL-Loss 186.4884, KL-Loss 0.0629, KL-Weight 0.6097
# TRAIN Epoch 05/20, ELBO 216.0738, NLL 216.0603, KL 0.0243, PPL 545.8096
# VALID Epoch 05/20, ELBO 212.9231, NLL 212.9113, KL 0.0194, PPL 471.3271
# TEST Epoch 05/20, ELBO 206.0939, NLL 206.0828, KL 0.0181, PPL 468.1034
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 236.5981, NLL-Loss 236.5918, KL-Loss 0.0105, KL-Weight 0.6100
# TRAIN Batch 0050/0370, ELBO-Loss 199.2431, NLL-Loss 199.2711, KL-Loss -0.0449, KL-Weight 0.6235
# TRAIN Batch 0100/0370, ELBO-Loss 223.1427, NLL-Loss 223.0810, KL-Loss 0.0969, KL-Weight 0.6370
# TRAIN Batch 0150/0370, ELBO-Loss 236.8234, NLL-Loss 236.8238, KL-Loss -0.0006, KL-Weight 0.6505
# TRAIN Batch 0200/0370, ELBO-Loss 205.9264, NLL-Loss 205.9291, KL-Loss -0.0041, KL-Weight 0.6641
# TRAIN Batch 0250/0370, ELBO-Loss 200.1926, NLL-Loss 200.1496, KL-Loss 0.0634, KL-Weight 0.6776
# TRAIN Batch 0300/0370, ELBO-Loss 219.0651, NLL-Loss 219.0782, KL-Loss -0.0189, KL-Weight 0.6911
# TRAIN Batch 0350/0370, ELBO-Loss 229.3621, NLL-Loss 229.3844, KL-Loss -0.0316, KL-Weight 0.7046
# TRAIN Batch 0369/0370, ELBO-Loss 229.5803, NLL-Loss 229.5716, KL-Loss 0.0122, KL-Weight 0.7097
# TRAIN Epoch 06/20, ELBO 214.1381, NLL 214.1242, KL 0.0211, PPL 515.8389
# VALID Epoch 06/20, ELBO 211.1031, NLL 211.0923, KL 0.0152, PPL 447.1817
# TEST Epoch 06/20, ELBO 204.3402, NLL 204.3306, KL 0.0136, PPL 444.2594
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 214.3821, NLL-Loss 214.3439, KL-Loss 0.0537, KL-Weight 0.7100
# TRAIN Batch 0050/0370, ELBO-Loss 204.3442, NLL-Loss 204.3266, KL-Loss 0.0243, KL-Weight 0.7235
# TRAIN Batch 0100/0370, ELBO-Loss 208.7889, NLL-Loss 208.7649, KL-Loss 0.0326, KL-Weight 0.7370
# TRAIN Batch 0150/0370, ELBO-Loss 206.1151, NLL-Loss 206.1374, KL-Loss -0.0297, KL-Weight 0.7505
# TRAIN Batch 0200/0370, ELBO-Loss 220.3280, NLL-Loss 220.3408, KL-Loss -0.0168, KL-Weight 0.7641
# TRAIN Batch 0250/0370, ELBO-Loss 229.5127, NLL-Loss 229.5139, KL-Loss -0.0015, KL-Weight 0.7776
# TRAIN Batch 0300/0370, ELBO-Loss 200.7851, NLL-Loss 200.7737, KL-Loss 0.0145, KL-Weight 0.7911
# TRAIN Batch 0350/0370, ELBO-Loss 182.1681, NLL-Loss 182.1636, KL-Loss 0.0055, KL-Weight 0.8046
# TRAIN Batch 0369/0370, ELBO-Loss 244.6801, NLL-Loss 244.6460, KL-Loss 0.0421, KL-Weight 0.8097
# TRAIN Epoch 07/20, ELBO 212.3916, NLL 212.3803, KL 0.0147, PPL 490.2563
# VALID Epoch 07/20, ELBO 209.5604, NLL 209.5419, KL 0.0229, PPL 427.5787
# TEST Epoch 07/20, ELBO 202.8411, NLL 202.8311, KL 0.0124, PPL 424.8222
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 205.7929, NLL-Loss 205.7487, KL-Loss 0.0546, KL-Weight 0.8100
# TRAIN Batch 0050/0370, ELBO-Loss 179.8767, NLL-Loss 179.8722, KL-Loss 0.0055, KL-Weight 0.8235
# TRAIN Batch 0100/0370, ELBO-Loss 168.1195, NLL-Loss 168.1735, KL-Loss -0.0645, KL-Weight 0.8370
# TRAIN Batch 0150/0370, ELBO-Loss 187.2360, NLL-Loss 187.2192, KL-Loss 0.0197, KL-Weight 0.8505
# TRAIN Batch 0200/0370, ELBO-Loss 226.5468, NLL-Loss 226.5445, KL-Loss 0.0027, KL-Weight 0.8641
# TRAIN Batch 0250/0370, ELBO-Loss 215.5103, NLL-Loss 215.5022, KL-Loss 0.0092, KL-Weight 0.8776
# TRAIN Batch 0300/0370, ELBO-Loss 224.5519, NLL-Loss 224.5483, KL-Loss 0.0041, KL-Weight 0.8911
# TRAIN Batch 0350/0370, ELBO-Loss 209.7315, NLL-Loss 209.7200, KL-Loss 0.0127, KL-Weight 0.9046
# TRAIN Batch 0369/0370, ELBO-Loss 216.2205, NLL-Loss 216.2635, KL-Loss -0.0472, KL-Weight 0.9097
# TRAIN Epoch 08/20, ELBO 210.8605, NLL 210.8471, KL 0.0156, PPL 468.8143
# VALID Epoch 08/20, ELBO 208.0265, NLL 208.0201, KL 0.0070, PPL 409.1749
# TEST Epoch 08/20, ELBO 201.4312, NLL 201.4211, KL 0.0110, PPL 407.3214
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 206.2084, NLL-Loss 206.1790, KL-Loss 0.0323, KL-Weight 0.9100
# TRAIN Batch 0050/0370, ELBO-Loss 233.2616, NLL-Loss 233.2629, KL-Loss -0.0014, KL-Weight 0.9235
# TRAIN Batch 0100/0370, ELBO-Loss 200.7608, NLL-Loss 200.7770, KL-Loss -0.0173, KL-Weight 0.9370
# TRAIN Batch 0150/0370, ELBO-Loss 208.8072, NLL-Loss 208.8024, KL-Loss 0.0050, KL-Weight 0.9505
# TRAIN Batch 0200/0370, ELBO-Loss 178.3367, NLL-Loss 178.3502, KL-Loss -0.0140, KL-Weight 0.9641
# TRAIN Batch 0250/0370, ELBO-Loss 182.3406, NLL-Loss 182.3772, KL-Loss -0.0375, KL-Weight 0.9776
# TRAIN Batch 0300/0370, ELBO-Loss 202.1307, NLL-Loss 202.1311, KL-Loss -0.0004, KL-Weight 0.9911
# TRAIN Batch 0350/0370, ELBO-Loss 214.1350, NLL-Loss 214.1403, KL-Loss -0.0052, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 162.9331, NLL-Loss 162.9450, KL-Loss -0.0119, KL-Weight 1.0000
# TRAIN Epoch 09/20, ELBO 209.3923, NLL 209.3786, KL 0.0144, PPL 449.1558
# VALID Epoch 09/20, ELBO 206.8212, NLL 206.8096, KL 0.0115, PPL 395.1028
# TEST Epoch 09/20, ELBO 200.2340, NLL 200.2222, KL 0.0118, PPL 393.0089
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 200.1562, NLL-Loss 200.1536, KL-Loss 0.0027, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 192.1353, NLL-Loss 192.1077, KL-Loss 0.0276, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 210.0413, NLL-Loss 210.0376, KL-Loss 0.0037, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 221.3084, NLL-Loss 221.2694, KL-Loss 0.0390, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 182.2200, NLL-Loss 182.2040, KL-Loss 0.0161, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 222.9160, NLL-Loss 222.9048, KL-Loss 0.0112, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 224.3697, NLL-Loss 224.3370, KL-Loss 0.0327, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 209.0590, NLL-Loss 209.0516, KL-Loss 0.0074, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 218.7617, NLL-Loss 218.7423, KL-Loss 0.0195, KL-Weight 1.0000
# TRAIN Epoch 10/20, ELBO 208.2475, NLL 208.2398, KL 0.0077, PPL 434.4815
# VALID Epoch 10/20, ELBO 206.1619, NLL 206.1616, KL 0.0003, PPL 387.7696
# TEST Epoch 10/20, ELBO 199.6477, NLL 199.6411, KL 0.0066, PPL 386.2529
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 197.4992, NLL-Loss 197.5010, KL-Loss -0.0019, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 212.9151, NLL-Loss 212.9093, KL-Loss 0.0057, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 224.7933, NLL-Loss 224.7895, KL-Loss 0.0037, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 217.5415, NLL-Loss 217.5348, KL-Loss 0.0067, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 159.4767, NLL-Loss 159.4660, KL-Loss 0.0107, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 180.9189, NLL-Loss 180.8932, KL-Loss 0.0257, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 192.6887, NLL-Loss 192.6868, KL-Loss 0.0018, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 249.7364, NLL-Loss 249.7708, KL-Loss -0.0344, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 249.0705, NLL-Loss 249.0100, KL-Loss 0.0605, KL-Weight 1.0000
# TRAIN Epoch 11/20, ELBO 207.6418, NLL 207.6338, KL 0.0080, PPL 426.8692
# VALID Epoch 11/20, ELBO 205.6298, NLL 205.6206, KL 0.0093, PPL 381.7511
# TEST Epoch 11/20, ELBO 199.1384, NLL 199.1342, KL 0.0042, PPL 380.4559
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 227.2137, NLL-Loss 227.2140, KL-Loss -0.0003, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 200.9516, NLL-Loss 200.9449, KL-Loss 0.0066, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 204.2492, NLL-Loss 204.2557, KL-Loss -0.0065, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 185.4731, NLL-Loss 185.4571, KL-Loss 0.0160, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 207.9984, NLL-Loss 208.0213, KL-Loss -0.0229, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 195.6385, NLL-Loss 195.6357, KL-Loss 0.0027, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 204.1980, NLL-Loss 204.2215, KL-Loss -0.0235, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 231.2214, NLL-Loss 231.2074, KL-Loss 0.0139, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 219.3851, NLL-Loss 219.3760, KL-Loss 0.0090, KL-Weight 1.0000
# TRAIN Epoch 12/20, ELBO 207.0382, NLL 207.0332, KL 0.0049, PPL 419.4560
# VALID Epoch 12/20, ELBO 205.3527, NLL 205.3472, KL 0.0054, PPL 378.7459
# TEST Epoch 12/20, ELBO 198.8668, NLL 198.8628, KL 0.0040, PPL 377.3870
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 220.2212, NLL-Loss 220.2077, KL-Loss 0.0135, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 193.8129, NLL-Loss 193.8148, KL-Loss -0.0019, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 214.9216, NLL-Loss 214.8983, KL-Loss 0.0233, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 213.1167, NLL-Loss 213.1011, KL-Loss 0.0155, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 231.6924, NLL-Loss 231.6696, KL-Loss 0.0228, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 216.4219, NLL-Loss 216.4220, KL-Loss -0.0000, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 192.9733, NLL-Loss 192.9458, KL-Loss 0.0275, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 212.5257, NLL-Loss 212.5306, KL-Loss -0.0049, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 197.4288, NLL-Loss 197.4615, KL-Loss -0.0328, KL-Weight 1.0000
# TRAIN Epoch 13/20, ELBO 206.7833, NLL 206.7790, KL 0.0043, PPL 416.3573
# VALID Epoch 13/20, ELBO 205.1087, NLL 205.1114, KL -0.0028, PPL 376.1727
# TEST Epoch 13/20, ELBO 198.6474, NLL 198.6426, KL 0.0048, PPL 374.9162
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 213.1052, NLL-Loss 213.1027, KL-Loss 0.0025, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 186.4477, NLL-Loss 186.4531, KL-Loss -0.0054, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 212.2421, NLL-Loss 212.2406, KL-Loss 0.0014, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 215.1199, NLL-Loss 215.0990, KL-Loss 0.0209, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 207.7587, NLL-Loss 207.7288, KL-Loss 0.0300, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 222.2871, NLL-Loss 222.2988, KL-Loss -0.0117, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 227.4642, NLL-Loss 227.4754, KL-Loss -0.0111, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 197.6949, NLL-Loss 197.6968, KL-Loss -0.0019, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 174.0439, NLL-Loss 174.0913, KL-Loss -0.0475, KL-Weight 1.0000
# TRAIN Epoch 14/20, ELBO 206.4968, NLL 206.4938, KL 0.0031, PPL 412.9073
# VALID Epoch 14/20, ELBO 204.9783, NLL 204.9728, KL 0.0055, PPL 374.6682
# TEST Epoch 14/20, ELBO 198.5108, NLL 198.5075, KL 0.0033, PPL 373.4083
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 226.6499, NLL-Loss 226.6351, KL-Loss 0.0148, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 258.8123, NLL-Loss 258.7919, KL-Loss 0.0204, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 206.4904, NLL-Loss 206.4667, KL-Loss 0.0236, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 191.7991, NLL-Loss 191.7910, KL-Loss 0.0081, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 214.4581, NLL-Loss 214.4679, KL-Loss -0.0098, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 206.3868, NLL-Loss 206.3606, KL-Loss 0.0262, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 200.8421, NLL-Loss 200.8411, KL-Loss 0.0010, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 220.4141, NLL-Loss 220.3956, KL-Loss 0.0185, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 194.9580, NLL-Loss 194.9629, KL-Loss -0.0049, KL-Weight 1.0000
# TRAIN Epoch 15/20, ELBO 206.3380, NLL 206.3342, KL 0.0038, PPL 410.9898
# VALID Epoch 15/20, ELBO 204.8433, NLL 204.8482, KL -0.0049, PPL 373.3208
# TEST Epoch 15/20, ELBO 198.3939, NLL 198.3921, KL 0.0018, PPL 372.1249
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 226.7596, NLL-Loss 226.7555, KL-Loss 0.0041, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 227.6297, NLL-Loss 227.6388, KL-Loss -0.0091, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 222.0467, NLL-Loss 222.0551, KL-Loss -0.0083, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 180.8325, NLL-Loss 180.7950, KL-Loss 0.0375, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 205.7814, NLL-Loss 205.7848, KL-Loss -0.0034, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 228.3576, NLL-Loss 228.3579, KL-Loss -0.0003, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 194.6309, NLL-Loss 194.6132, KL-Loss 0.0177, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 207.6354, NLL-Loss 207.6368, KL-Loss -0.0014, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 195.8050, NLL-Loss 195.8018, KL-Loss 0.0032, KL-Weight 1.0000
# TRAIN Epoch 16/20, ELBO 206.2242, NLL 206.2202, KL 0.0041, PPL 409.6250
# VALID Epoch 16/20, ELBO 204.7925, NLL 204.7885, KL 0.0040, PPL 372.6771
# TEST Epoch 16/20, ELBO 198.3342, NLL 198.3298, KL 0.0043, PPL 371.4337
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 179.7891, NLL-Loss 179.7572, KL-Loss 0.0319, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 219.8907, NLL-Loss 219.8961, KL-Loss -0.0053, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 179.5879, NLL-Loss 179.5894, KL-Loss -0.0015, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 200.2652, NLL-Loss 200.2620, KL-Loss 0.0032, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 178.9679, NLL-Loss 178.9746, KL-Loss -0.0067, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 235.9354, NLL-Loss 235.9029, KL-Loss 0.0325, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 191.9318, NLL-Loss 191.9354, KL-Loss -0.0036, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 227.6071, NLL-Loss 227.6053, KL-Loss 0.0018, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 215.8939, NLL-Loss 215.9036, KL-Loss -0.0097, KL-Weight 1.0000
# TRAIN Epoch 17/20, ELBO 206.1041, NLL 206.1008, KL 0.0034, PPL 408.2009
# VALID Epoch 17/20, ELBO 204.7289, NLL 204.7304, KL -0.0015, PPL 372.0521
# TEST Epoch 17/20, ELBO 198.2736, NLL 198.2724, KL 0.0012, PPL 370.7977
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 180.5350, NLL-Loss 180.5408, KL-Loss -0.0058, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 220.4106, NLL-Loss 220.4034, KL-Loss 0.0072, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 231.4550, NLL-Loss 231.4783, KL-Loss -0.0234, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 188.5080, NLL-Loss 188.4959, KL-Loss 0.0121, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 178.5007, NLL-Loss 178.4809, KL-Loss 0.0198, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 191.3690, NLL-Loss 191.4006, KL-Loss -0.0315, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 198.9493, NLL-Loss 198.9560, KL-Loss -0.0067, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 220.4794, NLL-Loss 220.4872, KL-Loss -0.0077, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 145.3630, NLL-Loss 145.3542, KL-Loss 0.0087, KL-Weight 1.0000
# TRAIN Epoch 18/20, ELBO 206.0758, NLL 206.0721, KL 0.0038, PPL 407.8595
# VALID Epoch 18/20, ELBO 204.7007, NLL 204.6996, KL 0.0011, PPL 371.7207
# TEST Epoch 18/20, ELBO 198.2418, NLL 198.2435, KL -0.0016, PPL 370.4779
#
#
# TRAIN Batch 0000/0370, ELBO-Loss 187.1064, NLL-Loss 187.1054, KL-Loss 0.0010, KL-Weight 1.0000
# TRAIN Batch 0050/0370, ELBO-Loss 186.8719, NLL-Loss 186.8681, KL-Loss 0.0038, KL-Weight 1.0000
# TRAIN Batch 0100/0370, ELBO-Loss 226.7272, NLL-Loss 226.7382, KL-Loss -0.0110, KL-Weight 1.0000
# TRAIN Batch 0150/0370, ELBO-Loss 207.7036, NLL-Loss 207.7189, KL-Loss -0.0153, KL-Weight 1.0000
# TRAIN Batch 0200/0370, ELBO-Loss 213.2897, NLL-Loss 213.2911, KL-Loss -0.0015, KL-Weight 1.0000
# TRAIN Batch 0250/0370, ELBO-Loss 198.2492, NLL-Loss 198.2309, KL-Loss 0.0183, KL-Weight 1.0000
# TRAIN Batch 0300/0370, ELBO-Loss 209.0049, NLL-Loss 209.0134, KL-Loss -0.0085, KL-Weight 1.0000
# TRAIN Batch 0350/0370, ELBO-Loss 189.1089, NLL-Loss 189.0899, KL-Loss 0.0189, KL-Weight 1.0000
# TRAIN Batch 0369/0370, ELBO-Loss 188.6091, NLL-Loss 188.6242, KL-Loss -0.0152, KL-Weight 1.0000
# TRAIN Epoch 19/20, ELBO 206.0649, NLL 206.0636, KL 0.0013, PPL 407.7588
# VALID Epoch 19/20, ELBO 204.6727, NLL 204.6701, KL 0.0026, PPL 371.4037
# TEST Epoch 19/20, ELBO 198.2187, NLL 198.2142, KL 0.0045, PPL 370.1547
#
#
# Total cost time 00 hr 03 min 55 sec

# %%
# calculate au

delta = 0.01
with torch.no_grad():
    model.eval()
    cnt = 0
    for itr, (enc_inputs, dec_inputs, targets, lengths) in enumerate(dataloaders['test']):
        bsize = enc_inputs.size(0)
        enc_inputs = enc_inputs.to(device)
        dec_inputs = dec_inputs.to(device)
        targets = targets.to(device)
        lengths = lengths.to(device)

        # forward
        logp, z, mu, logvar = model(enc_inputs, dec_inputs, lengths)
        
        if cnt == 0:
            mu_sum = mu.sum(dim=0, keepdim=True)
        else:
            mu_sum = mu_sum + mu.sum(dim=0, keepdim=True)
        cnt += mu.size(0)
        
    mu_mean = mu_sum / cnt
        
    cnt = 0
    for itr, (enc_inputs, dec_inputs, targets, lengths) in enumerate(dataloaders['test']):
        bsize = enc_inputs.size(0)
        enc_inputs = enc_inputs.to(device)
        dec_inputs = dec_inputs.to(device)
        targets = targets.to(device)
        lengths = lengths.to(device)

        # forward
        logp, z, mu, logvar = model(enc_inputs, dec_inputs, lengths)
        
        if cnt == 0:
            var_sum = ((mu - mu_mean) ** 2).sum(dim=0)
        else:
            var_sum = var_sum + ((mu - mu_mean) ** 2).sum(dim=0)
        cnt += mu.size(0)
        
    au_var = var_sum / (cnt - 1)
    
    print((au_var >= delta).sum().item())
    print(au_var)
# Out:
# 0
# tensor(1.00000e-04 *
#        [ 0.5958,  0.6127,  0.9107,  0.5410,  0.6681,  0.5592,  0.5364,
#          0.7720,  0.7045,  0.7054,  0.8317,  0.9439,  0.7149,  0.7737,
#          0.3722,  0.8960,  0.7263,  0.7583,  0.5083,  0.9493,  1.1184,
#          1.2833,  0.4535,  0.6717,  0.9164,  0.8861,  0.6781,  0.6442,
#          0.9394,  1.1537,  1.0354,  0.7714], device='cuda:0')

# %%
# plot KL curve
fig, ax1 = plt.subplots()
lns1 = ax1.plot(tracker['KL_weight'], 'b', label='KL term weight')
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('Step')
ax1.set_ylabel('KL term weight')
ax2 = ax1.twinx()
lns2 = ax2.plot(tracker['KL'], 'r', label='KL term value')
ax2.set_ylabel('KL term value')
lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, bbox_to_anchor=(0., 1.02, 1., .102),
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# latent space visualization
features = np.empty([len(datasets['test']), latent_dim])
for itr, (enc_inputs, dec_inputs, _, lengths) in enumerate(dataloaders['test']):
    enc_inputs = enc_inputs.to(device)
    dec_inputs = dec_inputs.to(device)
    lengths = lengths.to(device)
    _, _, mu, _ = model(enc_inputs, dec_inputs, lengths)
    start, end = batch_size * itr, batch_size * (itr + 1)
    features[start:end] = mu.data.cpu().numpy()
tsne_z = TSNE(n_components=2).fit_transform(features)
tracker['z'] = tsne_z

plt.figure()
plt.scatter(tsne_z[:, 0], tsne_z[:, 1], s=25, alpha=0.5)
plt.show()

# %%
# save learning results
sio.savemat("linear.mat", tracker)
