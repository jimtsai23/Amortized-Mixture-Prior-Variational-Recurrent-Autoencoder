# %%
import sys
sys.path.append('..')

# %%
import os
import time
import math
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from sklearn.manifold import TSNE
from multiprocessing import cpu_count

# %%
from ptb import PTB
from model import RNNVAE

# %%
# device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Penn TreeBank (PTB) dataset
data_path = '../data'
max_len = 96
splits = ['train', 'valid', 'test']
datasets = {split: PTB(root=data_path, split=split) for split in splits}

# %%
datasets
# Out:
# {'test': <ptb.PTB at 0x7f95c2edb0f0>,
#  'train': <ptb.PTB at 0x7f95ccee8588>,
#  'valid': <ptb.PTB at 0x7f95ce0230f0>}

# %%
# data loader
batch_size = 32
dataloaders = {split: DataLoader(datasets[split],
                                 batch_size=batch_size,
                                 shuffle=split=='train',
                                 num_workers=cpu_count(),
                                 pin_memory=torch.cuda.is_available())
                                 for split in splits}
symbols = datasets['train'].symbols

# %%
# RNNVAE model
embedding_size = 300
hidden_size = 256
latent_dim = 16
dropout_rate = 0.5
model = RNNVAE(vocab_size=datasets['train'].vocab_size,
               embed_size=embedding_size,
               time_step=max_len,
               hidden_size=hidden_size,
               z_dim=latent_dim,
               dropout_rate=dropout_rate,
               bos_idx=symbols['<bos>'],
               eos_idx=symbols['<eos>'],
               pad_idx=symbols['<pad>'])
model = model.to(device)
print(model)
# Out:
# RNNVAE(
#   (encoder): LSTMEncoder(
#     (embedding): Embedding(10002, 300, padding_idx=0)
#     (rnn): LSTM(300, 256, batch_first=True)
#     (output): Linear(in_features=512, out_features=32, bias=True)
#   )
#   (embedding): Embedding(10002, 300, padding_idx=0)
#   (init_h): Linear(in_features=16, out_features=256, bias=True)
#   (init_c): Linear(in_features=16, out_features=256, bias=True)
#   (rnn): LSTM(300, 256, batch_first=True)
#   (output): Linear(in_features=256, out_features=10002, bias=True)
# )

# %%
# folder to save model
save_path = 'vanilla'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
# objective function
learning_rate = 0.001
criterion = nn.NLLLoss(size_average=False, ignore_index=symbols['<pad>'])
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# negative log likelihood
def NLL(logp, target, length):
    target = target[:, :torch.max(length).item()].contiguous().view(-1)
    logp = logp.view(-1, logp.size(-1))
    return criterion(logp, target)

# KL divergence
def KL_div(mu, logvar):
    return -0.5 * torch.sum(1. + logvar - mu.pow(2) - logvar.exp())

# %%
# training setting
epoch = 20
print_every = 50

# %%
# training interface
step = 0
tracker = {'ELBO': [], 'NLL': [], 'KL': [], 'KL_weight': []}
start_time = time.time()
for ep in range(epoch):
    # learning rate decay
    if ep >= 10 and ep % 2 == 0:
        learning_rate = learning_rate * 0.5
        for param_group in optimizer.param_groups:
            param_group['lr'] = learning_rate

    for split in splits:
        dataloader = dataloaders[split]
        model.train() if split == 'train' else model.eval()
        totals = {'ELBO': 0., 'NLL': 0., 'KL': 0., 'words': 0}

        for itr, (enc_inputs, dec_inputs, targets, lengths) in enumerate(dataloader):
            bsize = enc_inputs.size(0)
            enc_inputs = enc_inputs.to(device)
            dec_inputs = dec_inputs.to(device)
            targets = targets.to(device)
            lengths = lengths.to(device)

            # forward
            logp, mu, logvar = model(enc_inputs, dec_inputs, lengths)

            # calculate loss
            NLL_loss = NLL(logp, targets, lengths + 1)
            KL_loss = KL_div(mu, logvar)
            KL_weight = 1.0
            loss = (NLL_loss + KL_weight * KL_loss) / bsize

            # cumulate
            totals['ELBO'] += loss.item() * bsize
            totals['NLL'] += NLL_loss.item()
            totals['KL'] += KL_loss.item()
            totals['words'] += torch.sum(lengths).item()

            # backward and optimize
            if split == 'train':
                step += 1
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), 5)
                optimizer.step()

                # track
                tracker['ELBO'].append(loss.item())
                tracker['NLL'].append(NLL_loss.item() / bsize)
                tracker['KL'].append(KL_loss.item() / bsize)
                tracker['KL_weight'].append(KL_weight)

                # print statistics
                if itr % print_every == 0 or itr + 1 == len(dataloader):
                    print("%s Batch %04d/%04d, ELBO-Loss %.4f, "
                          "NLL-Loss %.4f, KL-Loss %.4f, KL-Weight %.4f"
                          % (split.upper(), itr, len(dataloader),
                             tracker['ELBO'][-1], tracker['NLL'][-1],
                             tracker['KL'][-1], tracker['KL_weight'][-1]))

        samples = len(datasets[split])
        print("%s Epoch %02d/%02d, ELBO %.4f, NLL %.4f, KL %.4f, PPL %.4f"
              % (split.upper(), ep, epoch, totals['ELBO'] / samples,
                 totals['NLL'] / samples, totals['KL'] / samples,
                 math.exp(totals['NLL'] / totals['words'])))

    # save checkpoint
    checkpoint_path = os.path.join(save_path, "E%02d.pkl" % ep)
    torch.save(model.state_dict(), checkpoint_path)
    print("Model saved at %s\n" % checkpoint_path)
end_time = time.time()
print('Total cost time',
      time.strftime("%H hr %M min %S sec", time.gmtime(end_time - start_time)))
# Out:
# TRAIN Batch 0000/1315, ELBO-Loss 219.1998, NLL-Loss 218.9608, KL-Loss 0.2390, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 153.9350, NLL-Loss 153.8975, KL-Loss 0.0375, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 140.6095, NLL-Loss 140.5977, KL-Loss 0.0117, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 158.9307, NLL-Loss 158.9219, KL-Loss 0.0088, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 132.7484, NLL-Loss 132.7420, KL-Loss 0.0064, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 147.1936, NLL-Loss 147.1882, KL-Loss 0.0055, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 138.8059, NLL-Loss 138.8013, KL-Loss 0.0046, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss 143.5780, NLL-Loss 143.5746, KL-Loss 0.0035, KL-Weight 1.0000
# TRAIN Batch 0400/1315, ELBO-Loss 131.6525, NLL-Loss 131.6484, KL-Loss 0.0041, KL-Weight 1.0000
# TRAIN Batch 0450/1315, ELBO-Loss 123.9920, NLL-Loss 123.9885, KL-Loss 0.0035, KL-Weight 1.0000
# TRAIN Batch 0500/1315, ELBO-Loss 111.8315, NLL-Loss 111.8274, KL-Loss 0.0041, KL-Weight 1.0000
# TRAIN Batch 0550/1315, ELBO-Loss 125.4312, NLL-Loss 125.4275, KL-Loss 0.0037, KL-Weight 1.0000
# TRAIN Batch 0600/1315, ELBO-Loss 126.7978, NLL-Loss 126.7935, KL-Loss 0.0043, KL-Weight 1.0000
# TRAIN Batch 0650/1315, ELBO-Loss 112.0684, NLL-Loss 112.0654, KL-Loss 0.0029, KL-Weight 1.0000
# TRAIN Batch 0700/1315, ELBO-Loss 136.0161, NLL-Loss 136.0136, KL-Loss 0.0025, KL-Weight 1.0000
# TRAIN Batch 0750/1315, ELBO-Loss 130.5214, NLL-Loss 130.5186, KL-Loss 0.0028, KL-Weight 1.0000
# TRAIN Batch 0800/1315, ELBO-Loss 116.3716, NLL-Loss 116.3690, KL-Loss 0.0026, KL-Weight 1.0000
# TRAIN Batch 0850/1315, ELBO-Loss 111.8725, NLL-Loss 111.8702, KL-Loss 0.0023, KL-Weight 1.0000
# TRAIN Batch 0900/1315, ELBO-Loss
pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 112.1849, NLL-Loss 112.1848, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 102.7004, NLL-Loss 102.7003, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 92.5180, NLL-Loss 92.5179, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 94.1130, NLL-Loss 94.1129, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 96.2597, NLL-Loss 96.2597, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 105.7722, NLL-Loss 105.7721, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 91.5753, NLL-Loss 91.5751, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss 94.0357, NLL-Loss 94.0356, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0400/1315, ELBO-Loss 106.3102, NLL-Loss 106.3102, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0450/1315, ELBO-Loss 100.5844, NLL-Loss 100.5843, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 0500/1315, ELBO-Loss 107.2647, NLL-Loss 107.2647, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0550/1315, ELBO-Loss 93.5030, NLL-Loss 93.5029, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0600/1315, ELBO-Loss 93.3099, NLL-Loss 93.3098, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0650/1315, ELBO-Loss 102.0825, NLL-Loss 102.0825, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0700/1315, ELBO-Loss 102.4481, NLL-Loss 102.4480, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0750/1315, ELBO-Loss 87.7858, NLL-Loss 87.7857, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0800/1315, ELBO-Loss 95.5685, NLL-Loss 95.5684, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 0850/1315, ELBO-Loss 99.0629, NLL-Loss 99.0628, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 0900/1315, ELBO-Loss 95.0180, NLL-Loss 95.0179, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0950/1315, ELBO-Loss 98.3571, NLL-Loss 98.3570, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1000/1315, ELBO-Loss 96.2011, NLL-Loss 96.2010, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1050/1315, ELBO-Loss 89.1854, NLL-Loss 89.1853, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1100/1315, ELBO-Loss 101.4837, NLL-Loss 101.4836, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1150/1315, ELBO-Loss 125.2529, NLL-Loss 125.2528, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1200/1315, ELBO-Loss 100.9271, NLL-Loss 100.9270, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 77.2149, NLL-Loss 77.2149, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 95.5552, NLL-Loss 95.5551, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 94.2340, NLL-Loss 94.2339, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Epoch 17/20, ELBO 93.6092, NLL 93.6092, KL 0.0001, PPL 84.5229
# VALID Epoch 17/20, ELBO 107.9862, NLL 107.9861, KL 0.0001, PPL 175.9073
# TEST Epoch 17/20, ELBO 106.1764, NLL 106.1763, KL 0.0001, PPL 160.1429
# Model saved at vanilla/E17.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 91.6083, NLL-Loss 91.6082, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 81.4663, NLL-Loss 81.4663, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 81.2465, NLL-Loss 81.2464, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 86.2618, NLL-Loss 86.2617, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 99.6715, NLL-Loss 99.6715, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 99.8636, NLL-Loss 99.8635, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 94.6022, NLL-Loss 94.6021, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss 101.3466, NLL-Loss 101.3465, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0400/1315, ELBO-Loss 81.9203, NLL-Loss 81.9202, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0450/1315, ELBO-Loss 94.6685, NLL-Loss 94.6684, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 0500/1315, ELBO-Loss 89.5181, NLL-Loss 89.5180, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0550/1315, ELBO-Loss 98.0658, NLL-Loss 98.0658, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0600/1315, ELBO-Loss 96.4012, NLL-Loss 96.4012, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0650/1315, ELBO-Loss 84.3523, NLL-Loss 84.3522, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0700/1315, ELBO-Loss 97.5145, NLL-Loss 97.5144, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0750/1315, ELBO-Loss 105.0203, NLL-Loss 105.0203, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0800/1315, ELBO-Loss 88.5516, NLL-Loss 88.5515, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0850/1315, ELBO-Loss 95.2778, NLL-Loss 95.2777, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0900/1315, ELBO-Loss 97.5670, NLL-Loss 97.5669, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0950/1315, ELBO-Loss 99.1554, NLL-Loss 99.1554, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1000/1315, ELBO-Loss 83.8937, NLL-Loss 83.8937, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1050/1315, ELBO-Loss 97.1758, NLL-Loss 97.1757, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 1100/1315, ELBO-Loss 94.2903, NLL-Loss 94.2902, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1150/1315, ELBO-Loss 106.1621, NLL-Loss 106.1620, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1200/1315, ELBO-Loss 86.8588, NLL-Loss 86.8587, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 85.4823, NLL-Loss 85.4823, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 90.5059, NLL-Loss 90.5059, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 88.0002, NLL-Loss 88.0001, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Epoch 18/20, ELBO 93.4733, NLL 93.4732, KL 0.0001, PPL 83.9800
# VALID Epoch 18/20, ELBO 107.9838, NLL 107.9837, KL 0.0001, PPL 175.8866
# TEST Epoch 18/20, ELBO 106.1761, NLL 106.1760, KL 0.0001, PPL 160.1408
# Model saved at vanilla/E18.pkl
#
# TRAIN Batch 0000/1315, ELBO-Loss 103.1726, NLL-Loss 103.1726, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0050/1315, ELBO-Loss 113.7628, NLL-Loss 113.7627, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 0100/1315, ELBO-Loss 102.7095, NLL-Loss 102.7094, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0150/1315, ELBO-Loss 87.6645, NLL-Loss 87.6644, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0200/1315, ELBO-Loss 100.4970, NLL-Loss 100.4969, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0250/1315, ELBO-Loss 98.4628, NLL-Loss 98.4628, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 0300/1315, ELBO-Loss 80.7958, NLL-Loss 80.7957, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0350/1315, ELBO-Loss 100.4644, NLL-Loss 100.4643, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0400/1315, ELBO-Loss 83.6600, NLL-Loss 83.6600, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0450/1315, ELBO-Loss 79.9453, NLL-Loss 79.9452, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0500/1315, ELBO-Loss 86.3983, NLL-Loss 86.3983, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0550/1315, ELBO-Loss 101.2940, NLL-Loss 101.2940, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0600/1315, ELBO-Loss 85.4747, NLL-Loss 85.4746, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0650/1315, ELBO-Loss 85.3873, NLL-Loss 85.3872, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0700/1315, ELBO-Loss 84.2236, NLL-Loss 84.2235, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0750/1315, ELBO-Loss 96.0427, NLL-Loss 96.0427, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0800/1315, ELBO-Loss 92.1295, NLL-Loss 92.1294, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0850/1315, ELBO-Loss 90.7178, NLL-Loss 90.7178, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0900/1315, ELBO-Loss 102.8785, NLL-Loss 102.8784, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 0950/1315, ELBO-Loss 95.3818, NLL-Loss 95.3817, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1000/1315, ELBO-Loss 84.0781, NLL-Loss 84.0781, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1050/1315, ELBO-Loss 101.2715, NLL-Loss 101.2715, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 1100/1315, ELBO-Loss 98.1260, NLL-Loss 98.1259, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1150/1315, ELBO-Loss 102.0233, NLL-Loss 102.0232, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1200/1315, ELBO-Loss 107.2353, NLL-Loss 107.2352, KL-Loss 0.0000, KL-Weight 1.0000
# TRAIN Batch 1250/1315, ELBO-Loss 86.6508, NLL-Loss 86.6507, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1300/1315, ELBO-Loss 98.7884, NLL-Loss 98.7883, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Batch 1314/1315, ELBO-Loss 85.1630, NLL-Loss 85.1630, KL-Loss 0.0001, KL-Weight 1.0000
# TRAIN Epoch 19/20, ELBO 93.3982, NLL 93.3981, KL 0.0001, PPL 83.6815
# VALID Epoch 19/20, ELBO 107.9853, NLL 107.9853, KL 0.0001, PPL 175.9000
# TEST Epoch 19/20, ELBO 106.1740, NLL 106.1739, KL 0.0001, PPL 160.1244
# Model saved at vanilla/E19.pkl
#
# Total cost time 00 hr 19 min 21 sec

# %%
# plot KL curve
fig, ax1 = plt.subplots()
lns1 = ax1.plot(tracker['KL_weight'], 'b', label='KL term weight')
ax1.set_ylim([-0.05, 1.05])
ax1.set_xlabel('Step')
ax1.set_ylabel('KL term weight')
ax2 = ax1.twinx()
lns2 = ax2.plot(tracker['KL'], 'r', label='KL term value')
ax2.set_ylabel('KL term value')
lns = lns1 + lns2
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, bbox_to_anchor=(0., 1.02, 1., .102),
           ncol=2, mode="expand", borderaxespad=0.)
plt.show()

# %%
# latent space visualization
features = np.empty([len(datasets['test']), latent_dim])
for itr, (enc_inputs, dec_inputs, _, lengths) in enumerate(dataloaders['test']):
    enc_inputs = enc_inputs.to(device)
    dec_inputs = dec_inputs.to(device)
    lengths = lengths.to(device)
    _, mu, _ = model(enc_inputs, dec_inputs, lengths)
    start, end = batch_size * itr, batch_size * (itr + 1)
    features[start:end] = mu.data.cpu().numpy()
tsne_z = TSNE(n_components=2).fit_transform(features)
tracker['z'] = tsne_z

plt.figure()
plt.scatter(tsne_z[:, 0], tsne_z[:, 1], s=25, alpha=0.5)
plt.show()

# %%
# save learning results
sio.savemat("vanilla.mat", tracker)
